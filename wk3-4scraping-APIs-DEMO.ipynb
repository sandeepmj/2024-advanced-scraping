# %% [markdown]
# # Scraping APIs
#
# A site with an API (Application Programming Interface) wants you to scrape it.
#
# Examples abound:
#
# * <a href="https://www.census.gov/data/developers/data-sets.html">U.S. Census APIs</a>
# * <a href="https://apps.fas.usda.gov/opendataweb/home">US Agriculture Commodities and Exports</a>
# * <a href="https://www.federalregister.gov/developers/documentation/api/v1">Federal Register</a>
# * <a href="https://developer.dol.gov/beginners-guide/">Labor Department</a>
# * <a href="https://www.eia.gov/">U.S. Energy Information Department</a>
#
# Government sites tend  ```CSVs``` for download but their APIs offer more detailed options for data. They are not trying to hide the data.
#
# Private sites might have APIs, but often charge heafty prices for access beyond a basic number of downloads.
#
# The toughest/hardest part of scraping an API is that they ***ALL HAVE DIFFERENT INSTRUCTIONS*** on how to tap their data.
#
# Today, we'll explore different APIs that each build a different skill:
#
# 1. Census health data – **building a simple API call.**
# 2. USDA commodities exports – **using an API key and targeting specific commodities over several years.**
# 3. Federal Register – **tapping search terms.**
# 4. Energy Information Administration – **dealing with pagination.**
#
# What they all have in common:
#
# 1. a base url
# 2. a query string
# 3. tied together with a query character ```?```
# 4. an API key.
#
# Combined together these are known as an ```API endpoint```.
#
# You make an ```API call``` (a request) using the ```API endpoint```.

# %%
## import libraries
import requests
import pandas as pd
# from icecream import ic

# %% [markdown]
# ## 1. Census health data – **building a simple API call.**
#
# - <a href="https://www.census.gov/data/developers/data-sets/Health-Insurance-Statistics.html">Census health landing page</a>
# - List of <a href="https://api.census.gov/data/timeseries/healthins/sahie/variables.html">possible variables</a>
#
# We want to create a dataframe with the following info for every state in 2021:
#
# 1. Total number insured
# 2. Percent insured
# 3. Total number uninsured
# 4. Percent uninsured
# 5. by Race

# %% [markdown]
# ## the parts to build your API call.

# %%
## create a dictionary to know what codes mean
## all variables are 90% upper bound
target_dict = {
    "NIC_UB90": "total_insured",
    "PCTIC_PT": "pct_insured",
    "NUI_UB90": "total_uninsured",
    "PCTUI_PT": "pct_uninsured",
    "RACECAT": "race_cat",
    "RACE_DESC": "race_description",
    "STABREV": "state",
    "STATE": "fips_code"
    
}

# %%
## pull my keys

list(target_dict.keys())
# Out:
# ['NIC_UB90',
#  'PCTIC_PT',
#  'NUI_UB90',
#  'PCTUI_PT',
#  'RACECAT',
#  'RACE_DESC',
#  'STABREV',
#  'STATE']

# %%
target_dict.keys()
# Out:
# dict_keys(['NIC_UB90', 'PCTIC_PT', 'NUI_UB90', 'PCTUI_PT', 'RACECAT', 'RACE_DESC', 'STABREV', 'STATE'])

# %%
## pull values

list(target_dict.values())
# Out:
# ['total_insured',
#  'pct_insured',
#  'total_uninsured',
#  'pct_uninsured',
#  'race_cat',
#  'race_description',
#  'state',
#  'fips_code']

# %%
## format into api query format
target_vars = ",".join(target_dict.keys())
target_vars
# Out:
# 'NIC_UB90,PCTIC_PT,NUI_UB90,PCTUI_PT,RACECAT,RACE_DESC,STABREV,STATE'

# %%
## other targets

# %%
## base url + year

base_url= "https://api.census.gov/data/timeseries/healthins/sahie?get="
target_year = "2021"

# %%
## create query string
query_string = f"{target_vars}&for=state:*&time={target_year}"
query_string
# Out:
# 'NIC_UB90,PCTIC_PT,NUI_UB90,PCTUI_PT,RACECAT,RACE_DESC,STABREV,STATE&for=state:*&time=2021'

# %%
## create full API call
endpoint = base_url + query_string
endpoint
# Out:
# 'https://api.census.gov/data/timeseries/healthins/sahie?get=NIC_UB90,PCTIC_PT,NUI_UB90,PCTUI_PT,RACECAT,RACE_DESC,STABREV,STATE&for=state:*&time=2021'

# %%
## get response
response = requests.get(endpoint)

# %%
## turn response into json
data = response.json()
data
# Out:
# [['NIC_UB90',
#   'PCTIC_PT',
#   'NUI_UB90',
#   'PCTUI_PT',
#   'RACECAT',
#   'RACE_DESC',
#   'STABREV',
#   'STATE',
#   'time',
#   'state'],
#  ['3563072',
#   '88.3',
#   '484434',
#   '11.7',
#   '0',
#   'All Races',
#   'AL',
#   '01',
#   '2021',
#   '01'],
#  ['534609',
#   '86.8',
#   '84822',
#   '13.2',
#   '0',
#   'All Races',
#   'AK',
#   '02',
#   '2021',
#   '02'],
#  ['5035973',
#   '86.9',
#   '777974',
#   '13.1',
#   '0',
#   'All Races',
#   'AZ',
#   '04',
#   '2021',
#   '04'],
#  ['2169221',
#   '88.9',
#   '278814',
#   '11.1',
#   '0',
#   'All Races',
#   'AR',
#   '05',
#   '2021',
#   '05'],
#  ['30129212',
#   '91.9',
#   '2681093',
#   '8.1',
#   '0',
#   'All Races',
#   'CA',
#   '06',
#   '2021',
#   '06'],
#  ['4420952',
#   '90.7',
#   '467216',
#   '9.3',
#   '0',
#   'All Races',
#   'CO',
#   '08',
#   '2021',
#   '08'],
#  ['2711824',
#   '94.0',
#   '182120',
#   '6.0',
#   '0',
#   'All Races',
#   'CT',
#   '09',
#   '2021',
#   '09'],
#  ['728780',
#   '93.1',
#   '57747',
#   '6.9',
#   '0',
#   'All Races',
#   'DE',
#   '10',
#   '2021',
#   '10'],
#  ['530990',
#   '96.3',
#   '23332',
#   '3.7',
#   '0',
#   'All Races',
#   'DC',
#   '11',
#   '2021',
#   '11'],
#  ['14296034',
#   '84.9',
#   '2576054',
#   '15.1',
#   '0',
#   'All Races',
#   'FL',
#   '12',
#   '2021',
#   '12'],
#  ['7598069',
#   '85.2',
#   '1339829',
#   '14.8',
#   '0',
#   'All Races',
#   'GA',
#   '13',
#   '2021',
#   '13'],
#  ['1163928',
#   '95.6',
#   '57667',
#   '4.4',
#   '0',
#   'All Races',
#   'HI',
#   '15',
#   '2021',
#   '15'],
#  ['1412213',
#   '89.5',
#   '172189',
#   '10.5',
#   '0',
#   'All Races',
#   'ID',
#   '16',
#   '2021',
#   '16'],
#  ['9497054',
#   '91.8',
#   '865115',
#   '8.2',
#   '0',
#   'All Races',
#   'IL',
#   '17',
#   '2021',
#   '17'],
#  ['5067367',
#   '91.1',
#   '509404',
#   '8.9',
#   '0',
#   'All Races',
#   'IN',
#   '18',
#   '2021',
#   '18'],
#  ['2425414',
#   '94.2',
#   '154847',
#   '5.8',
#   '0',
#   'All Races',
#   'IA',
#   '19',
#   '2021',
#   '19'],
#  ['2145611',
#   '89.1',
#   '269918',
#   '10.9',
#   '0',
#   'All Races',
#   'KS',
#   '20',
#   '2021',
#   '20'],
#  ['3407687',
#   '93.2',
#   '257373',
#   '6.8',
#   '0',
#   'All Races',
#   'KY',
#   '21',
#   '2021',
#   '21'],
#  ['3384227',
#   '90.8',
#   '352563',
#   '9.2',
#   '0',
#   'All Races',
#   'LA',
#   '22',
#   '2021',
#   '22'],
#  ['982284',
#   '92.7',
#   '82469',
#   '7.3',
#   '0',
#   'All Races',
#   'ME',
#   '23',
#   '2021',
#   '23'],
#  ['4677457',
#   '93.0',
#   '362605',
#   '7.0',
#   '0',
#   'All Races',
#   'MD',
#   '24',
#   '2021',
#   '24'],
#  ['5429982',
#   '97.1',
#   '172020',
#   '2.9',
#   '0',
#   'All Races',
#   'MA',
#   '25',
#   '2021',
#   '25'],
#  ['7600114',
#   '94.0',
#   '500323',
#   '6.0',
#   '0',
#   'All Races',
#   'MI',
#   '26',
#   '2021',
#   '26'],
#  ['4433763',
#   '94.7',
#   '256264',
#   '5.3',
#   '0',
#   'All Races',
#   'MN',
#   '27',
#   '2021',
#   '27'],
#  ['2019016',
#   '85.7',
#   '348368',
#   '14.3',
#   '0',
#   'All Races',
#   'MS',
#   '28',
#   '2021',
#   '28'],
#  ['4418548',
#   '88.6',
#   '579723',
#   '11.4',
#   '0',
#   'All Races',
#   'MO',
#   '29',
#   '2021',
#   '29'],
#  ['778298',
#   '89.5',
#   '95919',
#   '10.5',
#   '0',
#   'All Races',
#   'MT',
#   '30',
#   '2021',
#   '30'],
#  ['1476623',
#   '91.5',
#   '141927',
#   '8.5',
#   '0',
#   'All Races',
#   'NE',
#   '31',
#   '2021',
#   '31'],
#  ['2258048',
#   '86.2',
#   '370658',
#   '13.8',
#   '0',
#   'All Races',
#   'NV',
#   '32',
#   '2021',
#   '32'],
#  ['1031569',
#   '93.7',
#   '74359',
#   '6.3',
#   '0',
#   'All Races',
#   'NH',
#   '33',
#   '2021',
#   '33'],
#  ['6934854',
#   '91.7',
#   '641059',
#   '8.3',
#   '0',
#   'All Races',
#   'NJ',
#   '34',
#   '2021',
#   '34'],
#  ['1451662',
#   '87.4',
#   '217559',
#   '12.6',
#   '0',
#   'All Races',
#   'NM',
#   '35',
#   '2021',
#   '35'],
#  ['14959089',
#   '93.9',
#   '998335',
#   '6.1',
#   '0',
#   'All Races',
#   'NY',
#   '36',
#   '2021',
#   '36'],
#  ['7441554',
#   '87.5',
#   '1080064',
#   '12.5',
#   '0',
#   'All Races',
#   'NC',
#   '37',
#   '2021',
#   '37'],
#  ['574139',
#   '90.8',
#   '61442',
#   '9.2',
#   '0',
#   'All Races',
#   'ND',
#   '38',
#   '2021',
#   '38'],
#  ['8740849',
#   '92.2',
#   '761759',
#   '7.8',
#   '0',
#   'All Races',
#   'OH',
#   '39',
#   '2021',
#   '39'],
#  ['2714125',
#   '83.1',
#   '559561',
#   '16.9',
#   '0',
#   'All Races',
#   'OK',
#   '40',
#   '2021',
#   '40'],
#  ['3186240',
#   '92.6',
#   '262937',
#   '7.4',
#   '0',
#   'All Races',
#   'OR',
#   '41',
#   '2021',
#   '41'],
#  ['9528187',
#   '93.3',
#   '699377',
#   '6.7',
#   '0',
#   'All Races',
#   'PA',
#   '42',
#   '2021',
#   '42'],
#  ['828172',
#   '95.1',
#   '46897',
#   '4.9',
#   '0',
#   'All Races',
#   'RI',
#   '44',
#   '2021',
#   '44'],
#  ['3599072',
#   '87.7',
#   '516249',
#   '12.3',
#   '0',
#   'All Races',
#   'SC',
#   '45',
#   '2021',
#   '45'],
#  ['630600',
#   '88.5',
#   '85274',
#   '11.5',
#   '0',
#   'All Races',
#   'SD',
#   '46',
#   '2021',
#   '46'],
#  ['4996923',
#   '88.1',
#   '688928',
#   '11.9',
#   '0',
#   'All Races',
#   'TN',
#   '47',
#   '2021',
#   '47'],
#  ['19990136',
#   '79.7',
#   '5141926',
#   '20.3',
#   '0',
#   'All Races',
#   'TX',
#   '48',
#   '2021',
#   '48'],
#  ['2633806',
#   '89.9',
#   '306158',
#   '10.1',
#   '0',
#   'All Races',
#   'UT',
#   '49',
#   '2021',
#   '49'],
#  ['474663',
#   '95.5',
#   '24699',
#   '4.5',
#   '0',
#   'All Races',
#   'VT',
#   '50',
#   '2021',
#   '50'],
#  ['6478078',
#   '92.0',
#   '575556',
#   '8.0',
#   '0',
#   'All Races',
#   'VA',
#   '51',
#   '2021',
#   '51'],
#  ['5959986',
#   '92.4',
#   '503031',
#   '7.6',
#   '0',
#   'All Races',
#   'WA',
#   '53',
#   '2021',
#   '53'],
#  ['1284534',
#   '92.3',
#   '113011',
#   '7.7',
#   '0',
#   'All Races',
#   'WV',
#   '54',
#   '2021',
#   '54'],
#  ['4432322',
#   '93.5',
#   '314853',
#   '6.5',
#   '0',
#   'All Races',
#   'WI',
#   '55',
#   '2021',
#   '55'],
#  ['398180',
#   '84.7',
#   '75825',
#   '15.3',
#   '0',
#   'All Races',
#   'WY',
#   '56',
#   '2021',
#   '56'],
#  ['2304125',
#   '90.0',
#   '264792',
#   '10.0',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'AL',
#   '01',
#   '2021',
#   '01'],
#  ['321988',
#   '90.1',
#   '37911',
#   '9.9',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'AK',
#   '02',
#   '2021',
#   '02'],
#  ['2550936',
#   '91.8',
#   '238689',
#   '8.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'AZ',
#   '04',
#   '2021',
#   '04'],
#  ['1532110',
#   '91.1',
#   '157398',
#   '8.9',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'AR',
#   '05',
#   '2021',
#   '05'],
#  ['9915067',
#   '95.6',
#   '471119',
#   '4.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'CA',
#   '06',
#   '2021',
#   '06'],
#  ['2917949',
#   '93.6',
#   '209842',
#   '6.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'CO',
#   '08',
#   '2021',
#   '08'],
#  ['1686251',
#   '96.3',
#   '70219',
#   '3.7',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'CT',
#   '09',
#   '2021',
#   '09'],
#  ['418296',
#   '94.6',
#   '26348',
#   '5.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'DE',
#   '10',
#   '2021',
#   '10'],
#  ['201183',
#   '97.8',
#   '5383',
#   '2.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'DC',
#   '11',
#   '2021',
#   '11'],
#  ['7026548',
#   '87.5',
#   '1024177',
#   '12.5',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'FL',
#   '12',
#   '2021',
#   '12'],
#  ['3843901',
#   '88.2',
#   '526239',
#   '11.8',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'GA',
#   '13',
#   '2021',
#   '13'],
#  ['209557',
#   '95.7',
#   '10549',
#   '4.3',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'HI',
#   '15',
#   '2021',
#   '15'],
#  ['1134753',
#   '91.6',
#   '109799',
#   '8.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'ID',
#   '16',
#   '2021',
#   '16'],
#  ['5611062',
#   '94.7',
#   '325650',
#   '5.3',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'IL',
#   '17',
#   '2021',
#   '17'],
#  ['3858445',
#   '92.1',
#   '341775',
#   '7.9',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'IN',
#   '18',
#   '2021',
#   '18'],
#  ['1999154',
#   '95.2',
#   '105322',
#   '4.8',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'IA',
#   '19',
#   '2021',
#   '19'],
#  ['1580219',
#   '91.6',
#   '150922',
#   '8.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'KS',
#   '20',
#   '2021',
#   '20'],
#  ['2819909',
#   '94.1',
#   '185148',
#   '5.9',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'KY',
#   '21',
#   '2021',
#   '21'],
#  ['1964665',
#   '92.6',
#   '165266',
#   '7.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'LA',
#   '22',
#   '2021',
#   '22'],
#  ['896004',
#   '92.9',
#   '72479',
#   '7.1',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'ME',
#   '23',
#   '2021',
#   '23'],
#  ['2246583',
#   '96.0',
#   '98783',
#   '4.0',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MD',
#   '24',
#   '2021',
#   '24'],
#  ['3651571',
#   '97.8',
#   '90075',
#   '2.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MA',
#   '25',
#   '2021',
#   '25'],
#  ['5522335',
#   '94.7',
#   '321970',
#   '5.3',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MI',
#   '26',
#   '2021',
#   '26'],
#  ['3374993',
#   '95.8',
#   '154121',
#   '4.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MN',
#   '27',
#   '2021',
#   '27'],
#  ['1131512',
#   '87.5',
#   '168679',
#   '12.5',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MS',
#   '28',
#   '2021',
#   '28'],
#  ['3441321',
#   '89.8',
#   '402717',
#   '10.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MO',
#   '29',
#   '2021',
#   '29'],
#  ['665032',
#   '90.9',
#   '70546',
#   '9.1',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'MT',
#   '30',
#   '2021',
#   '30'],
#  ['1125877',
#   '93.8',
#   '78616',
#   '6.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NE',
#   '31',
#   '2021',
#   '31'],
#  ['1002001',
#   '90.8',
#   '107342',
#   '9.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NV',
#   '32',
#   '2021',
#   '32'],
#  ['904604',
#   '94.2',
#   '59456',
#   '5.8',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NH',
#   '33',
#   '2021',
#   '33'],
#  ['3647628',
#   '95.6',
#   '177045',
#   '4.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NJ',
#   '34',
#   '2021',
#   '34'],
#  ['492097',
#   '93.3',
#   '38668',
#   '6.7',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NM',
#   '35',
#   '2021',
#   '35'],
#  ['7990480',
#   '96.0',
#   '342949',
#   '4.0',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NY',
#   '36',
#   '2021',
#   '36'],
#  ['4570296',
#   '90.6',
#   '488770',
#   '9.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'NC',
#   '37',
#   '2021',
#   '37'],
#  ['476882',
#   '92.4',
#   '41977',
#   '7.6',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'ND',
#   '38',
#   '2021',
#   '38'],
#  ['6674966',
#   '92.9',
#   '521000',
#   '7.1',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'OH',
#   '39',
#   '2021',
#   '39'],
#  ['1723828',
#   '87.1',
#   '262428',
#   '12.9',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'OK',
#   '40',
#   '2021',
#   '40'],
#  ['2264154',
#   '94.0',
#   '152617',
#   '6.0',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'OR',
#   '41',
#   '2021',
#   '41'],
#  ['6951076',
#   '94.3',
#   '435765',
#   '5.7',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'PA',
#   '42',
#   '2021',
#   '42'],
#  ['556951',
#   '96.4',
#   '23274',
#   '3.6',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'RI',
#   '44',
#   '2021',
#   '44'],
#  ['2258803',
#   '89.9',
#   '264003',
#   '10.1',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'SC',
#   '45',
#   '2021',
#   '45'],
#  ['515888',
#   '91.3',
#   '52050',
#   '8.7',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'SD',
#   '46',
#   '2021',
#   '46'],
#  ['3628684',
#   '90.0',
#   '416764',
#   '10.0',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'TN',
#   '47',
#   '2021',
#   '47'],
#  ['8213407',
#   '87.8',
#   '1165988',
#   '12.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'TX',
#   '48',
#   '2021',
#   '48'],
#  ['2054113',
#   '92.9',
#   '164461',
#   '7.1',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'UT',
#   '49',
#   '2021',
#   '49'],
#  ['431075',
#   '95.6',
#   '21789',
#   '4.4',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'VT',
#   '50',
#   '2021',
#   '50'],
#  ['3844422',
#   '94.4',
#   '237223',
#   '5.6',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'VA',
#   '51',
#   '2021',
#   '51'],
#  ['3781786',
#   '94.5',
#   '230901',
#   '5.5',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'WA',
#   '53',
#   '2021',
#   '53'],
#  ['1165353',
#   '92.5',
#   '100007',
#   '7.5',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'WV',
#   '54',
#   '2021',
#   '54'],
#  ['3487434',
#   '94.8',
#   '197977',
#   '5.2',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'WI',
#   '55',
#   '2021',
#   '55'],
#  ['332906',
#   '87.0',
#   '53069',
#   '13.0',
#   '1',
#   'White alone, not Hispanic or Latino',
#   'WY',
#   '56',
#   '2021',
#   '56'],
#  ['928974',
#   '87.1',
#   '143906',
#   '12.9',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'AL',
#   '01',
#   '2021',
#   '01'],
#  ['17090',
#   '85.9',
#   '3164',
#   '14.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'AK',
#   '02',
#   '2021',
#   '02'],
#  ['249474',
#   '88.7',
#   '34647',
#   '11.3',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'AZ',
#   '04',
#   '2021',
#   '04'],
#  ['333803',
#   '89.1',
#   '43867',
#   '10.9',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'AR',
#   '05',
#   '2021',
#   '05'],
#  ['1600553',
#   '93.5',
#   '117488',
#   '6.5',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'CA',
#   '06',
#   '2021',
#   '06'],
#  ['177884',
#   '90.7',
#   '20208',
#   '9.3',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'CO',
#   '08',
#   '2021',
#   '08'],
#  ['290881',
#   '93.4',
#   '22963',
#   '6.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'CT',
#   '09',
#   '2021',
#   '09'],
#  ['166829',
#   '93.6',
#   '12887',
#   '6.4',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'DE',
#   '10',
#   '2021',
#   '10'],
#  ['219958',
#   '95.9',
#   '11093',
#   '4.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'DC',
#   '11',
#   '2021',
#   '11'],
#  ['2310653',
#   '84.5',
#   '438771',
#   '15.5',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'FL',
#   '12',
#   '2021',
#   '12'],
#  ['2409812',
#   '85.2',
#   '432174',
#   '14.8',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'GA',
#   '13',
#   '2021',
#   '13'],
#  ['21425',
#   '95.4',
#   '1240',
#   '4.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'HI',
#   '15',
#   '2021',
#   '15'],
#  ['11144',
#   '87.4',
#   '1837',
#   '12.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'ID',
#   '16',
#   '2021',
#   '16'],
#  ['1290308',
#   '91.2',
#   '132388',
#   '8.8',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'IL',
#   '17',
#   '2021',
#   '17'],
#  ['491009',
#   '89.9',
#   '59213',
#   '10.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'IN',
#   '18',
#   '2021',
#   '18'],
#  ['103973',
#   '92.4',
#   '9676',
#   '7.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'IA',
#   '19',
#   '2021',
#   '19'],
#  ['116520',
#   '85.9',
#   '20902',
#   '14.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'KS',
#   '20',
#   '2021',
#   '20'],
#  ['275454',
#   '91.8',
#   '27296',
#   '8.2',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'KY',
#   '21',
#   '2021',
#   '21'],
#  ['1085972',
#   '91.0',
#   '113961',
#   '9.0',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'LA',
#   '22',
#   '2021',
#   '22'],
#  ['18936',
#   '91.2',
#   '2129',
#   '8.8',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'ME',
#   '23',
#   '2021',
#   '23'],
#  ['1396647',
#   '93.5',
#   '103082',
#   '6.5',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MD',
#   '24',
#   '2021',
#   '24'],
#  ['410559',
#   '96.0',
#   '19380',
#   '4.0',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MA',
#   '25',
#   '2021',
#   '25'],
#  ['1025166',
#   '92.9',
#   '84222',
#   '7.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MI',
#   '26',
#   '2021',
#   '26'],
#  ['335131',
#   '93.4',
#   '26069',
#   '6.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MN',
#   '27',
#   '2021',
#   '27'],
#  ['755952',
#   '84.6',
#   '143501',
#   '15.4',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MS',
#   '28',
#   '2021',
#   '28'],
#  ['494758',
#   '86.2',
#   '83634',
#   '13.8',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MO',
#   '29',
#   '2021',
#   '29'],
#  ['4505',
#   '86.0',
#   '846',
#   '14.0',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'MT',
#   '30',
#   '2021',
#   '30'],
#  ['74006',
#   '89.9',
#   '9295',
#   '10.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NE',
#   '31',
#   '2021',
#   '31'],
#  ['218869',
#   '87.9',
#   '32717',
#   '12.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NV',
#   '32',
#   '2021',
#   '32'],
#  ['16807',
#   '92.0',
#   '1716',
#   '8.0',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NH',
#   '33',
#   '2021',
#   '33'],
#  ['885142',
#   '91.6',
#   '86691',
#   '8.4',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NJ',
#   '34',
#   '2021',
#   '34'],
#  ['28899',
#   '89.6',
#   '3838',
#   '10.4',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NM',
#   '35',
#   '2021',
#   '35'],
#  ['2097517',
#   '93.4',
#   '157493',
#   '6.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NY',
#   '36',
#   '2021',
#   '36'],
#  ['1562195',
#   '87.4',
#   '234173',
#   '12.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'NC',
#   '37',
#   '2021',
#   '37'],
#  ['20438',
#   '86.0',
#   '3792',
#   '14.0',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'ND',
#   '38',
#   '2021',
#   '38'],
#  ['1096585',
#   '90.6',
#   '119993',
#   '9.4',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'OH',
#   '39',
#   '2021',
#   '39'],
#  ['196797',
#   '83.4',
#   '41375',
#   '16.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'OK',
#   '40',
#   '2021',
#   '40'],
#  ['64797',
#   '92.5',
#   '6023',
#   '7.5',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'OR',
#   '41',
#   '2021',
#   '41'],
#  ['1033879',
#   '92.8',
#   '86068',
#   '7.2',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'PA',
#   '42',
#   '2021',
#   '42'],
#  ['53052',
#   '95.2',
#   '3166',
#   '4.8',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'RI',
#   '44',
#   '2021',
#   '44'],
#  ['932352',
#   '87.2',
#   '144051',
#   '12.8',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'SC',
#   '45',
#   '2021',
#   '45'],
#  ['15770',
#   '83.5',
#   '3504',
#   '16.5',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'SD',
#   '46',
#   '2021',
#   '46'],
#  ['819401',
#   '87.0',
#   '128564',
#   '13.0',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'TN',
#   '47',
#   '2021',
#   '47'],
#  ['2481903',
#   '82.9',
#   '525045',
#   '17.1',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'TX',
#   '48',
#   '2021',
#   '48'],
#  ['30424',
#   '86.8',
#   '5193',
#   '13.2',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'UT',
#   '49',
#   '2021',
#   '49'],
#  ['6806',
#   '94.6',
#   '479',
#   '5.4',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'VT',
#   '50',
#   '2021',
#   '50'],
#  ['1201096',
#   '92.2',
#   '107453',
#   '7.8',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'VA',
#   '51',
#   '2021',
#   '51'],
#  ['242980',
#   '91.4',
#   '25318',
#   '8.6',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'WA',
#   '53',
#   '2021',
#   '53'],
#  ['42923',
#   '91.6',
#   '4551',
#   '8.4',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'WV',
#   '54',
#   '2021',
#   '54'],
#  ['286093',
#   '91.8',
#   '27836',
#   '8.2',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'WI',
#   '55',
#   '2021',
#   '55'],
#  ['3901',
#   '80.5',
#   '1062',
#   '19.5',
#   '2',
#   'Black or African American alone, not Hispanic or Latino',
#   'WY',
#   '56',
#   '2021',
#   '56'],
#  ['167335',
#   '73.3',
#   '63181',
#   '26.7',
#   '3',
#   'Hispanic or Latino (any race)',
#   'AL',
#   '01',
#   '2021',
#   '01'],
#  ['41149',
#   '79.6',
#   '11361',
#   '20.4',
#   '3',
#   'Hispanic or Latino (any race)',
#   'AK',
#   '02',
#   '2021',
#   '02'],
#  ['1718864',
#   '80.5',
#   '426325',
#   '19.5',
#   '3',
#   'Hispanic or Latino (any race)',
#   'AZ',
#   '04',
#   '2021',
#   '04'],
#  ['177315',
#   '73.9',
#   '65285',
#   '26.1',
#   '3',
#   'Hispanic or Latino (any race)',
#   'AR',
#   '05',
#   '2021',
#   '05'],
#  ['12433323',
#   '87.4',
#   '1815955',
#   '12.6',
#   '3',
#   'Hispanic or Latino (any race)',
#   'CA',
#   '06',
#   '2021',
#   '06'],
#  ['973683',
#   '82.3',
#   '216423',
#   '17.7',
#   '3',
#   'Hispanic or Latino (any race)',
#   'CO',
#   '08',
#   '2021',
#   '08'],
#  ['506516',
#   '86.8',
#   '81777',
#   '13.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'CT',
#   '09',
#   '2021',
#   '09'],
#  ['80154',
#   '84.3',
#   '16248',
#   '15.7',
#   '3',
#   'Hispanic or Latino (any race)',
#   'DE',
#   '10',
#   '2021',
#   '10'],
#  ['65465',
#   '92.7',
#   '6046',
#   '7.3',
#   '3',
#   'Hispanic or Latino (any race)',
#   'DC',
#   '11',
#   '2021',
#   '11'],
#  ['4057179',
#   '80.3',
#   '1011444',
#   '19.7',
#   '3',
#   'Hispanic or Latino (any race)',
#   'FL',
#   '12',
#   '2021',
#   '12'],
#  ['729982',
#   '70.0',
#   '319824',
#   '30.0',
#   '3',
#   'Hispanic or Latino (any race)',
#   'GA',
#   '13',
#   '2021',
#   '13'],
#  ['137493',
#   '92.9',
#   '11727',
#   '7.1',
#   '3',
#   'Hispanic or Latino (any race)',
#   'HI',
#   '15',
#   '2021',
#   '15'],
#  ['187985',
#   '79.1',
#   '52492',
#   '20.9',
#   '3',
#   'Hispanic or Latino (any race)',
#   'ID',
#   '16',
#   '2021',
#   '16'],
#  ['1746448',
#   '83.2',
#   '361454',
#   '16.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'IL',
#   '17',
#   '2021',
#   '17'],
#  ['408032',
#   '83.3',
#   '85882',
#   '16.7',
#   '3',
#   'Hispanic or Latino (any race)',
#   'IN',
#   '18',
#   '2021',
#   '18'],
#  ['174019',
#   '85.5',
#   '31671',
#   '14.5',
#   '3',
#   'Hispanic or Latino (any race)',
#   'IA',
#   '19',
#   '2021',
#   '19'],
#  ['275731',
#   '78.4',
#   '79133',
#   '21.6',
#   '3',
#   'Hispanic or Latino (any race)',
#   'KS',
#   '20',
#   '2021',
#   '20'],
#  ['142255',
#   '80.5',
#   '36487',
#   '19.5',
#   '3',
#   'Hispanic or Latino (any race)',
#   'KY',
#   '21',
#   '2021',
#   '21'],
#  ['174672',
#   '74.2',
#   '63078',
#   '25.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'LA',
#   '22',
#   '2021',
#   '22'],
#  ['21028',
#   '84.1',
#   '4403',
#   '15.9',
#   '3',
#   'Hispanic or Latino (any race)',
#   'ME',
#   '23',
#   '2021',
#   '23'],
#  ['511246',
#   '79.6',
#   '136330',
#   '20.4',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MD',
#   '24',
#   '2021',
#   '24'],
#  ['770456',
#   '94.2',
#   '51485',
#   '5.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MA',
#   '25',
#   '2021',
#   '25'],
#  ['459545',
#   '88.5',
#   '63373',
#   '11.5',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MI',
#   '26',
#   '2021',
#   '26'],
#  ['269297',
#   '85.2',
#   '49722',
#   '14.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MN',
#   '27',
#   '2021',
#   '27'],
#  ['65767',
#   '70.2',
#   '29116',
#   '29.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MS',
#   '28',
#   '2021',
#   '28'],
#  ['207476',
#   '77.8',
#   '61889',
#   '22.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MO',
#   '29',
#   '2021',
#   '29'],
#  ['36187',
#   '80.8',
#   '9369',
#   '19.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'MT',
#   '30',
#   '2021',
#   '30'],
#  ['178723',
#   '80.0',
#   '47039',
#   '20.0',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NE',
#   '31',
#   '2021',
#   '31'],
#  ['688246',
#   '78.8',
#   '191257',
#   '21.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NV',
#   '32',
#   '2021',
#   '32'],
#  ['48712',
#   '85.2',
#   '9380',
#   '14.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NH',
#   '33',
#   '2021',
#   '33'],
#  ['1471824',
#   '81.8',
#   '336673',
#   '18.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NJ',
#   '34',
#   '2021',
#   '34'],
#  ['776623',
#   '84.8',
#   '146216',
#   '15.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NM',
#   '35',
#   '2021',
#   '35'],
#  ['3015553',
#   '88.8',
#   '392729',
#   '11.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NY',
#   '36',
#   '2021',
#   '36'],
#  ['728572',
#   '71.3',
#   '299889',
#   '28.7',
#   '3',
#   'Hispanic or Latino (any race)',
#   'NC',
#   '37',
#   '2021',
#   '37'],
#  ['26795',
#   '79.8',
#   '7398',
#   '20.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'ND',
#   '38',
#   '2021',
#   '38'],
#  ['393507',
#   '83.7',
#   '80370',
#   '16.3',
#   '3',
#   'Hispanic or Latino (any race)',
#   'OH',
#   '39',
#   '2021',
#   '39'],
#  ['321226',
#   '72.9',
#   '122637',
#   '27.1',
#   '3',
#   'Hispanic or Latino (any race)',
#   'OK',
#   '40',
#   '2021',
#   '40'],
#  ['482048',
#   '86.0',
#   '83228',
#   '14.0',
#   '3',
#   'Hispanic or Latino (any race)',
#   'OR',
#   '41',
#   '2021',
#   '41'],
#  ['859483',
#   '86.4',
#   '141640',
#   '13.6',
#   '3',
#   'Hispanic or Latino (any race)',
#   'PA',
#   '42',
#   '2021',
#   '42'],
#  ['156282',
#   '90.2',
#   '18962',
#   '9.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'RI',
#   '44',
#   '2021',
#   '44'],
#  ['223204',
#   '72.0',
#   '89543',
#   '28.0',
#   '3',
#   'Hispanic or Latino (any race)',
#   'SC',
#   '45',
#   '2021',
#   '45'],
#  ['31110',
#   '78.8',
#   '9003',
#   '21.2',
#   '3',
#   'Hispanic or Latino (any race)',
#   'SD',
#   '46',
#   '2021',
#   '46'],
#  ['288363',
#   '70.9',
#   '121751',
#   '29.1',
#   '3',
#   'Hispanic or Latino (any race)',
#   'TN',
#   '47',
#   '2021',
#   '47'],
#  ['7537366',
#   '70.0',
#   '3252005',
#   '30.0',
#   '3',
#   'Hispanic or Latino (any race)',
#   'TX',
#   '48',
#   '2021',
#   '48'],
#  ['355542',
#   '76.1',
#   '115619',
#   '23.9',
#   '3',
#   'Hispanic or Latino (any race)',
#   'UT',
#   '49',
#   '2021',
#   '49'],
#  ['11345',
#   '90.2',
#   '1437',
#   '9.8',
#   '3',
#   'Hispanic or Latino (any race)',
#   'VT',
#   '50',
#   '2021',
#   '50'],
#  ['651682',
#   '79.0',
#   '178846',
#   '21.0',
#   '3',
#   'Hispanic or Latino (any race)',
#   'VA',
#   '51',
#   '2021',
#   '51'],
#  ['829022',
#   '83.0',
#   '176435',
#   '17.0',
#   '3',
#   'Hispanic or Latino (any race)',
#   'WA',
#   '53',
#   '2021',
#   '53'],
#  ['25538',
#   '84.7',
#   '5118',
#   '15.3',
#   '3',
#   'Hispanic or Latino (any race)',
#   'WV',
#   '54',
#   '2021',
#   '54'],
#  ['350978',
#   '84.1',
#   '69455',
#   '15.9',
#   '3',
#   'Hispanic or Latino (any race)',
#   'WI',
#   '55',
#   '2021',
#   '55'],
#  ['40640',
#   '71.4',
#   '17220',
#   '28.6',
#   '3',
#   'Hispanic or Latino (any race)',
#   'WY',
#   '56',
#   '2021',
#   '56'],
#  ['13550',
#   '83.7',
#   '2863',
#   '16.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'AL',
#   '01',
#   '2021',
#   '01'],
#  ['53578',
#   '74.8',
#   '18767',
#   '25.2',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'AK',
#   '02',
#   '2021',
#   '02'],
#  ['133770',
#   '73.7',
#   '49517',
#   '26.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'AZ',
#   '04',
#   '2021',
#   '04'],
#  ['11935',
#   '83.0',
#   '2649',
#   '17.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'AR',
#   '05',
#   '2021',
#   '05'],
#  ['81644',
#   '89.0',
#   '10972',
#   '11.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'CA',
#   '06',
#   '2021',
#   '06'],
#  ['18688',
#   '86.5',
#   '3211',
#   '13.5',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'CO',
#   '08',
#   '2021',
#   '08'],
#  ['4348',
#   '93.3',
#   '349',
#   '6.7',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'CT',
#   '09',
#   '2021',
#   '09'],
#  ['1429',
#   '91.0',
#   '161',
#   '9.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'DE',
#   '10',
#   '2021',
#   '10'],
#  ['686',
#   '94.4',
#   '46',
#   '5.6',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'DC',
#   '11',
#   '2021',
#   '11'],
#  ['25171',
#   '79.6',
#   '6905',
#   '20.4',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'FL',
#   '12',
#   '2021',
#   '12'],
#  ['11748',
#   '80.3',
#   '3115',
#   '19.7',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'GA',
#   '13',
#   '2021',
#   '13'],
#  ['1541',
#   '93.7',
#   '117',
#   '6.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'HI',
#   '15',
#   '2021',
#   '15'],
#  ['9993',
#   '82.0',
#   '2387',
#   '18.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'ID',
#   '16',
#   '2021',
#   '16'],
#  ['10027',
#   '89.3',
#   '1322',
#   '10.7',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'IL',
#   '17',
#   '2021',
#   '17'],
#  ['7537',
#   '85.4',
#   '1418',
#   '14.6',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'IN',
#   '18',
#   '2021',
#   '18'],
#  ['5290',
#   '89.4',
#   '691',
#   '10.6',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'IA',
#   '19',
#   '2021',
#   '19'],
#  ['11494',
#   '81.1',
#   '2894',
#   '18.9',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'KS',
#   '20',
#   '2021',
#   '20'],
#  ['4356',
#   '88.7',
#   '616',
#   '11.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'KY',
#   '21',
#   '2021',
#   '21'],
#  ['15440',
#   '83.8',
#   '3245',
#   '16.2',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'LA',
#   '22',
#   '2021',
#   '22'],
#  ['4616',
#   '88.8',
#   '651',
#   '11.2',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'ME',
#   '23',
#   '2021',
#   '23'],
#  ['7580',
#   '90.7',
#   '868',
#   '9.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MD',
#   '24',
#   '2021',
#   '24'],
#  ['6840',
#   '96.0',
#   '325',
#   '4.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MA',
#   '25',
#   '2021',
#   '25'],
#  ['29961',
#   '87.3',
#   '4743',
#   '12.7',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MI',
#   '26',
#   '2021',
#   '26'],
#  ['32147',
#   '85.7',
#   '5813',
#   '14.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MN',
#   '27',
#   '2021',
#   '27'],
#  ['7444',
#   '76.6',
#   '2443',
#   '23.4',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MS',
#   '28',
#   '2021',
#   '28'],
#  ['12698',
#   '78.9',
#   '3624',
#   '21.1',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MO',
#   '29',
#   '2021',
#   '29'],
#  ['32950',
#   '75.4',
#   '11354',
#   '24.6',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'MT',
#   '30',
#   '2021',
#   '30'],
#  ['8822',
#   '84.7',
#   '1733',
#   '15.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NE',
#   '31',
#   '2021',
#   '31'],
#  ['12950',
#   '80.9',
#   '3270',
#   '19.1',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NV',
#   '32',
#   '2021',
#   '32'],
#  ['1430',
#   '90.2',
#   '176',
#   '9.8',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NH',
#   '33',
#   '2021',
#   '33'],
#  ['7433',
#   '91.1',
#   '805',
#   '8.9',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NJ',
#   '34',
#   '2021',
#   '34'],
#  ['92954',
#   '78.7',
#   '26380',
#   '21.3',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NM',
#   '35',
#   '2021',
#   '35'],
#  ['31647',
#   '91.0',
#   '3450',
#   '9.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NY',
#   '36',
#   '2021',
#   '36'],
#  ['56222',
#   '78.9',
#   '15890',
#   '21.1',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'NC',
#   '37',
#   '2021',
#   '37'],
#  ['21109',
#   '78.3',
#   '6251',
#   '21.7',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'ND',
#   '38',
#   '2021',
#   '38'],
#  ['11022',
#   '86.8',
#   '1838',
#   '13.2',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'OH',
#   '39',
#   '2021',
#   '39'],
#  ['153036',
#   '67.0',
#   '76975',
#   '33.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'OK',
#   '40',
#   '2021',
#   '40'],
#  ['24229',
#   '89.5',
#   '3147',
#   '10.5',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'OR',
#   '41',
#   '2021',
#   '41'],
#  ['9489',
#   '90.1',
#   '1149',
#   '9.9',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'PA',
#   '42',
#   '2021',
#   '42'],
#  ['2528',
#   '94.0',
#   '184',
#   '6.0',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'RI',
#   '44',
#   '2021',
#   '44'],
#  ['9087',
#   '79.6',
#   '2507',
#   '20.4',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'SC',
#   '45',
#   '2021',
#   '45'],
#  ['34294',
#   '67.3',
#   '17252',
#   '32.7',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'SD',
#   '46',
#   '2021',
#   '46'],
#  ['9227',
#   '81.5',
#   '2272',
#   '18.5',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'TN',
#   '47',
#   '2021',
#   '47'],
#  ['45209',
#   '77.5',
#   '13916',
#   '22.5',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'TX',
#   '48',
#   '2021',
#   '48'],
#  ['16394',
#   '80.6',
#   '4248',
#   '19.4',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'UT',
#   '49',
#   '2021',
#   '49'],
#  ['1024',
#   '93.4',
#   '85',
#   '6.6',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'VT',
#   '50',
#   '2021',
#   '50'],
#  ['11423',
#   '88.8',
#   '1597',
#   '11.2',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'VA',
#   '51',
#   '2021',
#   '51'],
#  ['49383',
#   '84.8',
#   '9519',
#   '15.2',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'WA',
#   '53',
#   '2021',
#   '53'],
#  ['1701',
#   '87.9',
#   '264',
#   '12.1',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'WV',
#   '54',
#   '2021',
#   '54'],
#  ['27633',
#   '86.6',
#   '4640',
#   '13.4',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'WI',
#   '55',
#   '2021',
#   '55'],
#  ['5774',
#   '70.8',
#   '2505',
#   '29.2',
#   '4',
#   'American Indian and Alaska Native alone, not Hispanic or Latino',
#   'WY',
#   '56',
#   '2021',
#   '56'],
#  ['58686',
#   '89.8',
#   '7448',
#   '10.2',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'AL',
#   '01',
#   '2021',
#   '01'],
#  ['34842',
#   '87.4',
#   '5586',
#   '12.6',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'AK',
#   '02',
#   '2021',
#   '02'],
#  ['196810',
#   '91.5',
#   '20052',
#   '8.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'AZ',
#   '04',
#   '2021',
#   '04'],
#  ['40859',
#   '89.2',
#   '5587',
#   '10.8',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'AR',
#   '05',
#   '2021',
#   '05'],
#  ['4583012',
#   '95.7',
#   '216506',
#   '4.3',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'CA',
#   '06',
#   '2021',
#   '06'],
#  ['158059',
#   '93.1',
#   '13056',
#   '6.9',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'CO',
#   '08',
#   '2021',
#   '08'],
#  ['144912',
#   '95.3',
#   '8164',
#   '4.7',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'CT',
#   '09',
#   '2021',
#   '09'],
#  ['33193',
#   '94.9',
#   '2082',
#   '5.1',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'DE',
#   '10',
#   '2021',
#   '10'],
#  ['24127',
#   '97.0',
#   '908',
#   '3.0',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'DC',
#   '11',
#   '2021',
#   '11'],
#  ['460825',
#   '89.2',
#   '59721',
#   '10.8',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'FL',
#   '12',
#   '2021',
#   '12'],
#  ['370262',
#   '89.6',
#   '46234',
#   '10.4',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'GA',
#   '13',
#   '2021',
#   '13'],
#  ['342258',
#   '96.3',
#   '14653',
#   '3.7',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'HI',
#   '15',
#   '2021',
#   '15'],
#  ['21816',
#   '90.1',
#   '2752',
#   '9.9',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'ID',
#   '16',
#   '2021',
#   '16'],
#  ['580871',
#   '93.5',
#   '43638',
#   '6.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'IL',
#   '17',
#   '2021',
#   '17'],
#  ['144958',
#   '91.5',
#   '15033',
#   '8.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'IN',
#   '18',
#   '2021',
#   '18'],
#  ['70400',
#   '92.9',
#   '6124',
#   '7.1',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'IA',
#   '19',
#   '2021',
#   '19'],
#  ['71889',
#   '90.5',
#   '8413',
#   '9.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'KS',
#   '20',
#   '2021',
#   '20'],
#  ['61123',
#   '93.0',
#   '5246',
#   '7.0',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'KY',
#   '21',
#   '2021',
#   '21'],
#  ['64435',
#   '90.5',
#   '7547',
#   '9.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'LA',
#   '22',
#   '2021',
#   '22'],
#  ['14194',
#   '92.8',
#   '1294',
#   '7.2',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'ME',
#   '23',
#   '2021',
#   '23'],
#  ['325399',
#   '94.4',
#   '21339',
#   '5.6',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MD',
#   '24',
#   '2021',
#   '24'],
#  ['423419',
#   '97.5',
#   '12253',
#   '2.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MA',
#   '25',
#   '2021',
#   '25'],
#  ['277343',
#   '95.2',
#   '15408',
#   '4.8',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MI',
#   '26',
#   '2021',
#   '26'],
#  ['254847',
#   '94.6',
#   '16093',
#   '5.4',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MN',
#   '27',
#   '2021',
#   '27'],
#  ['23545',
#   '85.1',
#   '4607',
#   '14.9',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MS',
#   '28',
#   '2021',
#   '28'],
#  ['104778',
#   '90.3',
#   '12414',
#   '9.7',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MO',
#   '29',
#   '2021',
#   '29'],
#  ['8123',
#   '88.8',
#   '1181',
#   '11.2',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'MT',
#   '30',
#   '2021',
#   '30'],
#  ['42987',
#   '91.8',
#   '4386',
#   '8.2',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NE',
#   '31',
#   '2021',
#   '31'],
#  ['190006',
#   '89.2',
#   '25101',
#   '10.8',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NV',
#   '32',
#   '2021',
#   '32'],
#  ['34166',
#   '93.1',
#   '2960',
#   '6.9',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NH',
#   '33',
#   '2021',
#   '33'],
#  ['748234',
#   '95.0',
#   '42308',
#   '5.0',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NJ',
#   '34',
#   '2021',
#   '34'],
#  ['25935',
#   '91.8',
#   '2677',
#   '8.2',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NM',
#   '35',
#   '2021',
#   '35'],
#  ['1376816',
#   '93.8',
#   '97188',
#   '6.2',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NY',
#   '36',
#   '2021',
#   '36'],
#  ['277260',
#   '91.7',
#   '27324',
#   '8.3',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'NC',
#   '37',
#   '2021',
#   '37'],
#  ['10152',
#   '90.1',
#   '1295',
#   '9.9',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'ND',
#   '38',
#   '2021',
#   '38'],
#  ['244616',
#   '91.8',
#   '24027',
#   '8.2',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'OH',
#   '39',
#   '2021',
#   '39'],
#  ['71334',
#   '86.6',
#   '11955',
#   '13.4',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'OK',
#   '40',
#   '2021',
#   '40'],
#  ['162720',
#   '94.7',
#   '10316',
#   '5.3',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'OR',
#   '41',
#   '2021',
#   '41'],
#  ['395100',
#   '93.5',
#   '30244',
#   '6.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'PA',
#   '42',
#   '2021',
#   '42'],
#  ['30666',
#   '95.9',
#   '1590',
#   '4.1',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'RI',
#   '44',
#   '2021',
#   '44'],
#  ['72428',
#   '87.5',
#   '11458',
#   '12.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'SC',
#   '45',
#   '2021',
#   '45'],
#  ['11720',
#   '87.5',
#   '1904',
#   '12.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'SD',
#   '46',
#   '2021',
#   '46'],
#  ['105610',
#   '89.7',
#   '13420',
#   '10.3',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'TN',
#   '47',
#   '2021',
#   '47'],
#  ['1200204',
#   '89.9',
#   '141489',
#   '10.1',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'TX',
#   '48',
#   '2021',
#   '48'],
#  ['66814',
#   '90.6',
#   '7844',
#   '9.4',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'UT',
#   '49',
#   '2021',
#   '49'],
#  ['10295',
#   '95.7',
#   '567',
#   '4.3',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'VT',
#   '50',
#   '2021',
#   '50'],
#  ['478363',
#   '93.2',
#   '37681',
#   '6.8',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'VA',
#   '51',
#   '2021',
#   '51'],
#  ['604773',
#   '94.4',
#   '39229',
#   '5.6',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'WA',
#   '53',
#   '2021',
#   '53'],
#  ['11622',
#   '92.2',
#   '1159',
#   '7.8',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'WV',
#   '54',
#   '2021',
#   '54'],
#  ['152174',
#   '93.1',
#   '12536',
#   '6.9',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'WI',
#   '55',
#   '2021',
#   '55'],
#  ['4169',
#   '83.5',
#   '931',
#   '16.5',
#   '5',
#   'Asian alone, not Hispanic or Latino',
#   'WY',
#   '56',
#   '2021',
#   '56'],
#  ['1842',
#   '84.9',
#   '375',
#   '15.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'AL',
#   '01',
#   '2021',
#   '01'],
#  ['8508',
#   '83.6',
#   '1863',
#   '16.4',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'AK',
#   '02',
#   '2021',
#   '02'],
#  ['9575',
#   '86.0',
#   '1785',
#   '14.0',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'AZ',
#   '04',
#   '2021',
#   '04'],
#  ['8792',
#   '80.2',
#   '2383',
#   '19.8',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'AR',
#   '05',
#   '2021',
#   '05'],
#  ['107437',
#   '91.7',
#   '11235',
#   '8.3',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'CA',
#   '06',
#   '2021',
#   '06'],
#  ['6763',
#   '90.0',
#   '872',
#   '10.0',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'CO',
#   '08',
#   '2021',
#   '08'],
#  ['974',
#   '93.9',
#   '77',
#   '6.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'CT',
#   '09',
#   '2021',
#   '09'],
#  ['256',
#   '89.6',
#   '34',
#   '10.4',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'DE',
#   '10',
#   '2021',
#   '10'],
#  ['227',
#   '96.6',
#   '10',
#   '3.4',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'DC',
#   '11',
#   '2021',
#   '11'],
#  ['9920',
#   '83.8',
#   '2214',
#   '16.2',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'FL',
#   '12',
#   '2021',
#   '12'],
#  ['5428',
#   '82.1',
#   '1342',
#   '17.9',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'GA',
#   '13',
#   '2021',
#   '13'],
#  ['98590',
#   '93.2',
#   '8341',
#   '6.8',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'HI',
#   '15',
#   '2021',
#   '15'],
#  ['2516',
#   '84.9',
#   '509',
#   '15.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'ID',
#   '16',
#   '2021',
#   '16'],
#  ['2683',
#   '90.5',
#   '330',
#   '9.5',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'IL',
#   '17',
#   '2021',
#   '17'],
#  ['2063',
#   '87.5',
#   '341',
#   '12.5',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'IN',
#   '18',
#   '2021',
#   '18'],
#  ['4327',
#   '89.5',
#   '578',
#   '10.5',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'IA',
#   '19',
#   '2021',
#   '19'],
#  ['2312',
#   '85.0',
#   '459',
#   '15.0',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'KS',
#   '20',
#   '2021',
#   '20'],
#  ['2621',
#   '89.3',
#   '363',
#   '10.7',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'KY',
#   '21',
#   '2021',
#   '21'],
#  ['1264',
#   '86.9',
#   '221',
#   '13.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'LA',
#   '22',
#   '2021',
#   '22'],
#  ['330',
#   '90.5',
#   '41',
#   '9.5',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'ME',
#   '23',
#   '2021',
#   '23'],
#  ['2209',
#   '91.6',
#   '238',
#   '8.4',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MD',
#   '24',
#   '2021',
#   '24'],
#  ['2355',
#   '96.5',
#   '104',
#   '3.5',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MA',
#   '25',
#   '2021',
#   '25'],
#  ['2058',
#   '91.4',
#   '231',
#   '8.6',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MI',
#   '26',
#   '2021',
#   '26'],
#  ['2619',
#   '92.1',
#   '261',
#   '7.9',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MN',
#   '27',
#   '2021',
#   '27'],
#  ['714',
#   '78.9',
#   '216',
#   '21.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MS',
#   '28',
#   '2021',
#   '28'],
#  ['6584',
#   '83.4',
#   '1466',
#   '16.6',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MO',
#   '29',
#   '2021',
#   '29'],
#  ['557',
#   '84.5',
#   '117',
#   '15.5',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'MT',
#   '30',
#   '2021',
#   '30'],
#  ['1001',
#   '88.4',
#   '156',
#   '11.6',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NE',
#   '31',
#   '2021',
#   '31'],
#  ['15267',
#   '83.8',
#   '3301',
#   '16.2',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NV',
#   '32',
#   '2021',
#   '32'],
#  ['302',
#   '90.2',
#   '39',
#   '9.8',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NH',
#   '33',
#   '2021',
#   '33'],
#  ['2444',
#   '91.8',
#   '256',
#   '8.2',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NJ',
#   '34',
#   '2021',
#   '34'],
#  ['952',
#   '87.6',
#   '155',
#   '12.4',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NM',
#   '35',
#   '2021',
#   '35'],
#  ['6908',
#   '92.3',
#   '669',
#   '7.7',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NY',
#   '36',
#   '2021',
#   '36'],
#  ['5323',
#   '84.9',
#   '1082',
#   '15.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'NC',
#   '37',
#   '2021',
#   '37'],
#  ['433',
#   '85.1',
#   '85',
#   '14.9',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'ND',
#   '38',
#   '2021',
#   '38'],
#  ['4007',
#   '88.7',
#   '590',
#   '11.3',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'OH',
#   '39',
#   '2021',
#   '39'],
#  ['5510',
#   '76.8',
#   '1807',
#   '23.2',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'OK',
#   '40',
#   '2021',
#   '40'],
#  ['13626',
#   '90.8',
#   '1601',
#   '9.2',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'OR',
#   '41',
#   '2021',
#   '41'],
#  ['2975',
#   '91.6',
#   '316',
#   '8.4',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'PA',
#   '42',
#   '2021',
#   '42'],
#  ['516',
#   '95.0',
#   '33',
#   '5.0',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'RI',
#   '44',
#   '2021',
#   '44'],
#  ['2168',
#   '82.6',
#   '518',
#   '17.4',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'SC',
#   '45',
#   '2021',
#   '45'],
#  ['417',
#   '82.0',
#   '103',
#   '18.0',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'SD',
#   '46',
#   '2021',
#   '46'],
#  ['2747',
#   '83.9',
#   '601',
#   '16.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'TN',
#   '47',
#   '2021',
#   '47'],
#  ['19048',
#   '80.8',
#   '5135',
#   '19.2',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'TX',
#   '48',
#   '2021',
#   '48'],
#  ['26352',
#   '85.9',
#   '4963',
#   '14.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'UT',
#   '49',
#   '2021',
#   '49'],
#  ['125',
#   '96.1',
#   '7',
#   '3.9',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'VT',
#   '50',
#   '2021',
#   '50'],
#  ['4515',
#   '89.8',
#   '609',
#   '10.2',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'VA',
#   '51',
#   '2021',
#   '51'],
#  ['43162',
#   '89.9',
#   '5564',
#   '10.1',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'WA',
#   '53',
#   '2021',
#   '53'],
#  ['253',
#   '89.5',
#   '35',
#   '10.5',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'WV',
#   '54',
#   '2021',
#   '54'],
#  ['1641',
#   '90.3',
#   '206',
#   '9.7',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'WI',
#   '55',
#   '2021',
#   '55'],
#  ['261',
#   '79.0',
#   '79',
#   '21.0',
#   '6',
#   'Native Hawaiian and Other Pacific Islander alone, not Hispanic or Latino',
#   'WY',
#   '56',
#   '2021',
#   '56'],
#  ['98324',
#   '90.3',
#   '11633',
#   '9.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'AL',
#   '01',
#   '2021',
#   '01'],
#  ['60639',
#   '87.8',
#   '9355',
#   '12.2',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'AK',
#   '02',
#   '2021',
#   '02'],
#  ['191902',
#   '90.3',
#   '22317',
#   '9.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'AZ',
#   '04',
#   '2021',
#   '04'],
#  ['71553',
#   '89.9',
#   '8791',
#   '10.1',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'AR',
#   '05',
#   '2021',
#   '05'],
#  ['1442365',
#   '95.5',
#   '72007',
#   '4.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'CA',
#   '06',
#   '2021',
#   '06'],
#  ['177794',
#   '93.6',
#   '13472',
#   '6.4',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'CO',
#   '08',
#   '2021',
#   '08'],
#  ['83638',
#   '95.7',
#   '4267',
#   '4.3',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'CT',
#   '09',
#   '2021',
#   '09'],
#  ['30769',
#   '94.3',
#   '2133',
#   '5.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'DE',
#   '10',
#   '2021',
#   '10'],
#  ['20244',
#   '97.0',
#   '746',
#   '3.0',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'DC',
#   '11',
#   '2021',
#   '11'],
#  ['441069',
#   '87.3',
#   '68153',
#   '12.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'FL',
#   '12',
#   '2021',
#   '12'],
#  ['250505',
#   '88.6',
#   '34470',
#   '11.4',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'GA',
#   '13',
#   '2021',
#   '13'],
#  ['356277',
#   '96.6',
#   '14253',
#   '3.4',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'HI',
#   '15',
#   '2021',
#   '15'],
#  ['47701',
#   '89.7',
#   '6108',
#   '10.3',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'ID',
#   '16',
#   '2021',
#   '16'],
#  ['272974',
#   '94.4',
#   '17652',
#   '5.6',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'IL',
#   '17',
#   '2021',
#   '17'],
#  ['165801',
#   '91.8',
#   '16220',
#   '8.2',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'IN',
#   '18',
#   '2021',
#   '18'],
#  ['72206',
#   '94.5',
#   '4740',
#   '5.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'IA',
#   '19',
#   '2021',
#   '19'],
#  ['93947',
#   '88.2',
#   '13696',
#   '11.8',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'KS',
#   '20',
#   '2021',
#   '20'],
#  ['107576',
#   '93.9',
#   '7824',
#   '6.1',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'KY',
#   '21',
#   '2021',
#   '21'],
#  ['86726',
#   '92.2',
#   '8192',
#   '7.8',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'LA',
#   '22',
#   '2021',
#   '22'],
#  ['28326',
#   '92.5',
#   '2622',
#   '7.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'ME',
#   '23',
#   '2021',
#   '23'],
#  ['198178',
#   '94.7',
#   '12350',
#   '5.3',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MD',
#   '24',
#   '2021',
#   '24'],
#  ['170741',
#   '97.8',
#   '4357',
#   '2.2',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MA',
#   '25',
#   '2021',
#   '25'],
#  ['294574',
#   '93.8',
#   '21244',
#   '6.2',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MI',
#   '26',
#   '2021',
#   '26'],
#  ['171965',
#   '94.3',
#   '11421',
#   '5.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MN',
#   '27',
#   '2021',
#   '27'],
#  ['41373',
#   '86.5',
#   '7097',
#   '13.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MS',
#   '28',
#   '2021',
#   '28'],
#  ['161178',
#   '87.7',
#   '24224',
#   '12.3',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MO',
#   '29',
#   '2021',
#   '29'],
#  ['32951',
#   '89.1',
#   '4513',
#   '10.9',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'MT',
#   '30',
#   '2021',
#   '30'],
#  ['49029',
#   '92.4',
#   '4524',
#   '7.6',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NE',
#   '31',
#   '2021',
#   '31'],
#  ['140893',
#   '89.6',
#   '17854',
#   '10.4',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NV',
#   '32',
#   '2021',
#   '32'],
#  ['27063',
#   '93.5',
#   '2147',
#   '6.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NH',
#   '33',
#   '2021',
#   '33'],
#  ['186372',
#   '94.8',
#   '11504',
#   '5.2',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NJ',
#   '34',
#   '2021',
#   '34'],
#  ['39013',
#   '90.9',
#   '4436',
#   '9.1',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NM',
#   '35',
#   '2021',
#   '35'],
#  ['462116',
#   '95.1',
#   '25805',
#   '4.9',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NY',
#   '36',
#   '2021',
#   '36'],
#  ['261811',
#   '89.5',
#   '33061',
#   '10.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'NC',
#   '37',
#   '2021',
#   '37'],
#  ['20040',
#   '90.6',
#   '2354',
#   '9.4',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'ND',
#   '38',
#   '2021',
#   '38'],
#  ['329837',
#   '92.8',
#   '27632',
#   '7.2',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'OH',
#   '39',
#   '2021',
#   '39'],
#  ['254254',
#   '83.1',
#   '54244',
#   '16.9',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'OK',
#   '40',
#   '2021',
#   '40'],
#  ['181436',
#   '94.1',
#   '12775',
#   '5.9',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'OR',
#   '41',
#   '2021',
#   '41'],
#  ['290351',
#   '94.5',
#   '18361',
#   '5.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'PA',
#   '42',
#   '2021',
#   '42'],
#  ['29762',
#   '96.5',
#   '1273',
#   '3.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'RI',
#   '44',
#   '2021',
#   '44'],
#  ['112215',
#   '88.8',
#   '15354',
#   '11.2',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'SC',
#   '45',
#   '2021',
#   '45'],
#  ['23729',
#   '87.5',
#   '3786',
#   '12.5',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'SD',
#   '46',
#   '2021',
#   '46'],
#  ['155589',
#   '90.3',
#   '18254',
#   '9.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'TN',
#   '47',
#   '2021',
#   '47'],
#  ['538624',
#   '87.1',
#   '83973',
#   '12.9',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'TX',
#   '48',
#   '2021',
#   '48'],
#  ['91197',
#   '90.3',
#   '10860',
#   '9.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'UT',
#   '49',
#   '2021',
#   '49'],
#  ['14350',
#   '96.1',
#   '692',
#   '3.9',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'VT',
#   '50',
#   '2021',
#   '50'],
#  ['301181',
#   '92.4',
#   '26751',
#   '7.6',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'VA',
#   '51',
#   '2021',
#   '51'],
#  ['422280',
#   '94.0',
#   '29465',
#   '6.0',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'WA',
#   '53',
#   '2021',
#   '53'],
#  ['38653',
#   '92.9',
#   '3386',
#   '7.1',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'WV',
#   '54',
#   '2021',
#   '54'],
#  ['133676',
#   '94.0',
#   '9510',
#   '6.0',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'WI',
#   '55',
#   '2021',
#   '55'],
#  ['12069',
#   '84.3',
#   '2499',
#   '15.7',
#   '7',
#   'Two or More Races, not Hispanic or Latino',
#   'WY',
#   '56',
#   '2021',
#   '56']]

# %%
## create dataframe
df = pd.DataFrame(data[1:], columns = data[0])
# df = pd.DataFrame(data)
df
# Out:
#      NIC_UB90 PCTIC_PT NUI_UB90 PCTUI_PT RACECAT  \
# 0     3563072     88.3   484434     11.7       0
# 1      534609     86.8    84822     13.2       0
# 2     5035973     86.9   777974     13.1       0
# 3     2169221     88.9   278814     11.1       0
# 4    30129212     91.9  2681093      8.1       0
# ..        ...      ...      ...      ...     ...
# 403    301181     92.4    26751      7.6       7
# 404    422280     94.0    29465      6.0       7
# 405     38653     92.9     3386      7.1       7
# 406    133676     94.0     9510      6.0       7
# 407     12069     84.3     2499     15.7       7
#
#                                      RACE_DESC STABREV STATE  time state
# 0                                    All Races      AL    01  2021    01
# 1                                    All Races      AK    02  2021    02
# 2                                    All Races      AZ    04  2021    04
# 3                                    All Races      AR    05  2021    05
# 4                                    All Races      CA    06  2021    06
# ..                                         ...     ...   ...   ...   ...
# 403  Two or More Races, not Hispanic or Latino      VA    51  2021    51
# 404  Two or More Races, not Hispanic or Latino      WA    53  2021    53
# 405  Two or More Races, not Hispanic or Latino      WV    54  2021    54
# 406  Two or More Races, not Hispanic or Latino      WI    55  2021    55
# 407  Two or More Races, not Hispanic or Latino      WY    56  2021    56
#
# [408 rows x 10 columns]

# %%
## rename column headers with more meaning full headers
df.rename(columns = target_dict, inplace = True)
df
# Out:
#     total_insured pct_insured total_uninsured pct_uninsured race_cat  \
# 0         3563072        88.3          484434          11.7        0
# 1          534609        86.8           84822          13.2        0
# 2         5035973        86.9          777974          13.1        0
# 3         2169221        88.9          278814          11.1        0
# 4        30129212        91.9         2681093           8.1        0
# ..            ...         ...             ...           ...      ...
# 403        301181        92.4           26751           7.6        7
# 404        422280        94.0           29465           6.0        7
# 405         38653        92.9            3386           7.1        7
# 406        133676        94.0            9510           6.0        7
# 407         12069        84.3            2499          15.7        7
#
#                               race_description state fips_code  time state
# 0                                    All Races    AL        01  2021    01
# 1                                    All Races    AK        02  2021    02
# 2                                    All Races    AZ        04  2021    04
# 3                                    All Races    AR        05  2021    05
# 4                                    All Races    CA        06  2021    06
# ..                                         ...   ...       ...   ...   ...
# 403  Two or More Races, not Hispanic or Latino    VA        51  2021    51
# 404  Two or More Races, not Hispanic or Latino    WA        53  2021    53
# 405  Two or More Races, not Hispanic or Latino    WV        54  2021    54
# 406  Two or More Races, not Hispanic or Latino    WI        55  2021    55
# 407  Two or More Races, not Hispanic or Latino    WY        56  2021    56
#
# [408 rows x 10 columns]

# %%
df_list = []
for target_year in range(2018,2023):
    print(target_year)
    print(base_url + f"{target_vars}&for=state:*&time={target_year}")
    response = requests.get(base_url + f"{target_vars}&for=state:*&time={target_year}")
    data = response.json()
    df = pd.DataFrame(data[1:], columns = data[0])
    df.rename(columns = target_dict, inplace = True)
    df_list.append(df)
# Out:
# 2018
# https://api.census.gov/data/timeseries/healthins/sahie?get=NIC_UB90,PCTIC_PT,NUI_UB90,PCTUI_PT,RACECAT,RACE_DESC,STABREV,STATE&for=state:*&time=2018
# 2019
# https://api.census.gov/data/timeseries/healthins/sahie?get=NIC_UB90,PCTIC_PT,NUI_UB90,PCTUI_PT,RACECAT,RACE_DESC,STABREV,STATE&for=state:*&time=2019
# 2020
# https://api.census.gov/data/timeseries/healthins/sahie?get=NIC_UB90,PCTIC_PT,NUI_UB90,PCTUI_PT,RACECAT,RACE_DESC,STABREV,STATE&for=state:*&time=2020
# 2021
# https://api.census.gov/data/timeseries/healthins/sahie?get=NIC_UB90,PCTIC_PT,NUI_UB90,PCTUI_PT,RACECAT,RACE_DESC,STABREV,STATE&for=state:*&time=2021
# 2022
# https://api.census.gov/data/timeseries/healthins/sahie?get=NIC_UB90,PCTIC_PT,NUI_UB90,PCTUI_PT,RACECAT,RACE_DESC,STABREV,STATE&for=state:*&time=2022

# %%
len(df_list)
# Out:
# 5

# %%
df = pd.concat(df_list, ignore_index = True)
df
# Out:
#      total_insured pct_insured total_uninsured pct_uninsured race_cat  \
# 0          3498430        88.1          483417          11.9        0
# 1           551881        86.1           92699          13.9        0
# 2          5043389        87.2          756267          12.8        0
# 3          2204505        90.4          242681           9.6        0
# 4         30505401        91.7         2812946           8.3        0
# ...            ...         ...             ...           ...      ...
# 1423         12522        86.9            2109          13.1        7
# 1424          4022        82.7             955          17.3        2
# 1425       6843590        94.3          423868           5.7        1
# 1426       1036963        93.4           79701           6.6        2
# 1427        333716        87.8           49207          12.2        1
#
#                                        race_description state fips_code  time  \
# 0                                             All Races    AL        01  2018
# 1                                             All Races    AK        02  2018
# 2                                             All Races    AZ        04  2018
# 3                                             All Races    AR        05  2018
# 4                                             All Races    CA        06  2018
# ...                                                 ...   ...       ...   ...
# 1423          Two or More Races, not Hispanic or Latino    WY        56  2022
# 1424  Black or African American alone, not Hispanic ...    WY        56  2022
# 1425                White alone, not Hispanic or Latino    PA        42  2022
# 1426  Black or African American alone, not Hispanic ...    PA        42  2022
# 1427                White alone, not Hispanic or Latino    WY        56  2022
#
#      state
# 0       01
# 1       02
# 2       04
# 3       05
# 4       06
# ...    ...
# 1423    56
# 1424    56
# 1425    42
# 1426    42
# 1427    56
#
# [1428 rows x 10 columns]

# %%
## cooy race category column to be converted to description next cell

# %%
## replace with codes

# %% [markdown]
# ### 2. USDA commodities exports – **using an API key and targeting specific commodities over several years.**
#
# - <a href="https://apps.fas.usda.gov/opendataweb/home">USDA APIs endpoints</a>
# - Get an <a href="https://apps.fas.usda.gov/opendataweb/home">API key</a>
#
# We want to create a dataframe with exports between 2020-2022 to all countries for the following commodities:
#
# 1. All Wheat
# 2. Oats
# 3. Cuts of Beef
# 4. Cuts of Pork

# %%
## find the parts to build your API call

headers = {
    'accept': 'application/json',
    'X-Api-Key': 'lx8NMObcTL9PSZSCZzJyykInlqLEx5WZZKtbGITw',
}

response = requests.get('https://api.fas.usda.gov/api/esr/commodities', headers=headers)

# %%
target_commodities = [{'commodityCode': 107, 'commodityName': 'All Wheat', 'unitId': 1},
{'commodityCode': 601, 'commodityName': 'Oats', 'unitId': 1},
{'commodityCode': 1701,
  'commodityName': 'Fresh, Chilled, or Frozen Muscle Cuts of Beef',
  'unitId': 1},
 {'commodityCode': 1702,
  'commodityName': 'Fresh, Chilled, or Frozen Muscle Cuts of Pork',
  'unitId': 1}]

# %%
base_url = "https://api.fas.usda.gov/api/esr/exports/commodityCode/"
end_url = "/allCountries/marketYear/"

# %%
headers = {
        'accept': 'application/json',
        'X-Api-Key': 'lx8NMObcTL9PSZSCZzJyykInlqLEx5WZZKtbGITw',
        }

all_data = []
for year in range(2020, 2022):
    for target_com  in target_commodities:
        endpoint = f'{base_url}{target_com.get("commodityCode")}{end_url}{year}'
        print(endpoint)
        

        response = requests.get(
        endpoint,
        headers=headers,)
        
        all_data.append(response.json())
# Out:
# https://api.fas.usda.gov/api/esr/exports/commodityCode/107/allCountries/marketYear/2020
# https://api.fas.usda.gov/api/esr/exports/commodityCode/601/allCountries/marketYear/2020
# https://api.fas.usda.gov/api/esr/exports/commodityCode/1701/allCountries/marketYear/2020
# https://api.fas.usda.gov/api/esr/exports/commodityCode/1702/allCountries/marketYear/2020
# https://api.fas.usda.gov/api/esr/exports/commodityCode/107/allCountries/marketYear/2021
# https://api.fas.usda.gov/api/esr/exports/commodityCode/601/allCountries/marketYear/2021
# https://api.fas.usda.gov/api/esr/exports/commodityCode/1701/allCountries/marketYear/2021
# https://api.fas.usda.gov/api/esr/exports/commodityCode/1702/allCountries/marketYear/2021

# %%
all_data
# Out:
# [[{'commodityCode': 107,
#    'countryCode': 1220,
#    'weeklyExports': 199,
#    'accumulatedExports': 199,
#    'outstandingSales': 18885,
#    'grossNewSales': 11268,
#    'currentMYNetSales': 10391,
#    'currentMYTotalCommitment': 19084,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2010,
#    'weeklyExports': 71970,
#    'accumulatedExports': 71970,
#    'outstandingSales': 688745,
#    'grossNewSales': 365035,
#    'currentMYNetSales': 90031,
#    'currentMYTotalCommitment': 760715,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2050,
#    'weeklyExports': 3300,
#    'accumulatedExports': 3300,
#    'outstandingSales': 15600,
#    'grossNewSales': 8800,
#    'currentMYNetSales': 300,
#    'currentMYTotalCommitment': 18900,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2110,
#    'weeklyExports': 6600,
#    'accumulatedExports': 6600,
#    'outstandingSales': 23000,
#    'grossNewSales': 16551,
#    'currentMYNetSales': 600,
#    'currentMYTotalCommitment': 29600,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2150,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 112056,
#    'grossNewSales': 9278,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 112056,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2190,
#    'weeklyExports': 1582,
#    'accumulatedExports': 1582,
#    'outstandingSales': 3765,
#    'grossNewSales': 1631,
#    'currentMYNetSales': 82,
#    'currentMYTotalCommitment': 5347,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2230,
#    'weeklyExports': 45,
#    'accumulatedExports': 45,
#    'outstandingSales': 30050,
#    'grossNewSales': 48,
#    'currentMYNetSales': -3,
#    'currentMYTotalCommitment': 30095,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2250,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 136100,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 136100,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2410,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 16000,
#    'grossNewSales': 11000,
#    'currentMYNetSales': 11000,
#    'currentMYTotalCommitment': 16000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2470,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 24950,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 24950,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2480,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 16900,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 16900,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2720,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 3200,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 3200,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2740,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 36800,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 36800,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2830,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 27680,
#    'grossNewSales': 16680,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 27680,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3010,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 155500,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 155500,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3310,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 12500,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 12500,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3330,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 40750,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 40750,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3370,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 64000,
#    'grossNewSales': 1000,
#    'currentMYNetSales': 1000,
#    'currentMYTotalCommitment': 64000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3510,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 45000,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 45000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 4750,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 80000,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 80000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5050,
#    'weeklyExports': 105000,
#    'accumulatedExports': 105000,
#    'outstandingSales': 150000,
#    'grossNewSales': 110000,
#    'currentMYNetSales': 55000,
#    'currentMYTotalCommitment': 255000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5170,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 55000,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 55000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5460,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 23557,
#    'grossNewSales': 22557,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 23557,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5490,
#    'weeklyExports': 27500,
#    'accumulatedExports': 27500,
#    'outstandingSales': 168090,
#    'grossNewSales': 12500,
#    'currentMYNetSales': 2500,
#    'currentMYTotalCommitment': 195590,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5520,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 89000,
#    'grossNewSales': 59000,
#    'currentMYNetSales': 30000,
#    'currentMYTotalCommitment': 89000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5570,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 93000,
#    'grossNewSales': 93000,
#    'currentMYNetSales': 30000,
#    'currentMYTotalCommitment': 93000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5600,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 283500,
#    'grossNewSales': 240500,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 283500,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5650,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 737000,
#    'grossNewSales': 187000,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 737000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5800,
#    'weeklyExports': 37733,
#    'accumulatedExports': 37733,
#    'outstandingSales': 269091,
#    'grossNewSales': 87254,
#    'currentMYNetSales': 733,
#    'currentMYTotalCommitment': 306824,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5820,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 540,
#    'grossNewSales': 540,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 540,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5830,
#    'weeklyExports': 56680,
#    'accumulatedExports': 56680,
#    'outstandingSales': 187768,
#    'grossNewSales': 1749,
#    'currentMYNetSales': 56680,
#    'currentMYTotalCommitment': 244448,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5880,
#    'weeklyExports': 46393,
#    'accumulatedExports': 46393,
#    'outstandingSales': 478143,
#    'grossNewSales': 189676,
#    'currentMYNetSales': 112140,
#    'currentMYTotalCommitment': 524536,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 7210,
#    'weeklyExports': 23100,
#    'accumulatedExports': 23100,
#    'outstandingSales': 261000,
#    'grossNewSales': 53100,
#    'currentMYNetSales': 2100,
#    'currentMYTotalCommitment': 284100,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 7290,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 20000,
#    'grossNewSales': 0,
#    'currentMYNetSales': 20000,
#    'currentMYTotalCommitment': 20000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 7530,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 481270,
#    'grossNewSales': 83900,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 481270,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 919575,
#    'grossNewSales': 353299,
#    'currentMYNetSales': -97199,
#    'currentMYTotalCommitment': 919575,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-06T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 1220,
#    'weeklyExports': 200,
#    'accumulatedExports': 399,
#    'outstandingSales': 18685,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 19084,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2010,
#    'weeklyExports': 61113,
#    'accumulatedExports': 133083,
#    'outstandingSales': 659185,
#    'grossNewSales': 52118,
#    'currentMYNetSales': 31553,
#    'currentMYTotalCommitment': 792268,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2050,
#    'weeklyExports': 0,
#    'accumulatedExports': 3300,
#    'outstandingSales': 46300,
#    'grossNewSales': 0,
#    'currentMYNetSales': 30700,
#    'currentMYTotalCommitment': 49600,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2080,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 4500,
#    'grossNewSales': 4500,
#    'currentMYNetSales': 4500,
#    'currentMYTotalCommitment': 4500,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2110,
#    'weeklyExports': 0,
#    'accumulatedExports': 6600,
#    'outstandingSales': 38300,
#    'grossNewSales': 0,
#    'currentMYNetSales': 15300,
#    'currentMYTotalCommitment': 44900,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2150,
#    'weeklyExports': 9150,
#    'accumulatedExports': 9150,
#    'outstandingSales': 106023,
#    'grossNewSales': 3117,
#    'currentMYNetSales': 3117,
#    'currentMYTotalCommitment': 115173,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2190,
#    'weeklyExports': 0,
#    'accumulatedExports': 1582,
#    'outstandingSales': 3765,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 5347,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2230,
#    'weeklyExports': 0,
#    'accumulatedExports': 45,
#    'outstandingSales': 35050,
#    'grossNewSales': 5000,
#    'currentMYNetSales': 5000,
#    'currentMYTotalCommitment': 35095,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2250,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 137100,
#    'grossNewSales': 1000,
#    'currentMYNetSales': 1000,
#    'currentMYTotalCommitment': 137100,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2410,
#    'weeklyExports': 8686,
#    'accumulatedExports': 8686,
#    'outstandingSales': 23000,
#    'grossNewSales': 12097,
#    'currentMYNetSales': 15686,
#    'currentMYTotalCommitment': 31686,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2450,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2470,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 43350,
#    'grossNewSales': 18400,
#    'currentMYNetSales': 18400,
#    'currentMYTotalCommitment': 43350,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2480,
#    'weeklyExports': 500,
#    'accumulatedExports': 500,
#    'outstandingSales': 18400,
#    'grossNewSales': 2000,
#    'currentMYNetSales': 2000,
#    'currentMYTotalCommitment': 18900,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2720,
#    'weeklyExports': 1800,
#    'accumulatedExports': 1800,
#    'outstandingSales': 3900,
#    'grossNewSales': 2500,
#    'currentMYNetSales': 2500,
#    'currentMYTotalCommitment': 5700,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2740,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 43100,
#    'grossNewSales': 6300,
#    'currentMYNetSales': 6300,
#    'currentMYTotalCommitment': 43100,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2830,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 27680,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 27680,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3010,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 155500,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 155500,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3070,
#    'weeklyExports': 6315,
#    'accumulatedExports': 6315,
#    'outstandingSales': 0,
#    'grossNewSales': 6315,
#    'currentMYNetSales': 6315,
#    'currentMYTotalCommitment': 6315,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3120,
#    'weeklyExports': 6314,
#    'accumulatedExports': 6314,
#    'outstandingSales': 0,
#    'grossNewSales': 107,
#    'currentMYNetSales': 6314,
#    'currentMYTotalCommitment': 6314,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3310,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 17500,
#    'grossNewSales': 5000,
#    'currentMYNetSales': 5000,
#    'currentMYTotalCommitment': 17500,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3330,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 43050,
#    'grossNewSales': 2300,
#    'currentMYNetSales': 2300,
#    'currentMYTotalCommitment': 43050,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3370,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 64000,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 64000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3510,
#    'weeklyExports': 13939,
#    'accumulatedExports': 13939,
#    'outstandingSales': 31061,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 45000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3550,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3570,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 4120,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 7499,
#    'grossNewSales': 7499,
#    'currentMYNetSales': 7499,
#    'currentMYTotalCommitment': 7499,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 4230,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 4270,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 4710,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 4750,
#    'weeklyExports': 19446,
#    'accumulatedExports': 19446,
#    'outstandingSales': 70000,
#    'grossNewSales': 9529,
#    'currentMYNetSales': 9446,
#    'currentMYTotalCommitment': 89446,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 4910,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5050,
#    'weeklyExports': 52500,
#    'accumulatedExports': 157500,
#    'outstandingSales': 100000,
#    'grossNewSales': 2500,
#    'currentMYNetSales': 2500,
#    'currentMYTotalCommitment': 257500,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5080,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5170,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 55000,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 55000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5200,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5210,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 58400,
#    'grossNewSales': 58400,
#    'currentMYNetSales': 58400,
#    'currentMYTotalCommitment': 58400,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5420,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5460,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 23536,
#    'grossNewSales': 0,
#    'currentMYNetSales': -21,
#    'currentMYTotalCommitment': 23536,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5490,
#    'weeklyExports': 27500,
#    'accumulatedExports': 55000,
#    'outstandingSales': 143340,
#    'grossNewSales': 2750,
#    'currentMYNetSales': 2750,
#    'currentMYTotalCommitment': 198340,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5520,
#    'weeklyExports': 42965,
#    'accumulatedExports': 42965,
#    'outstandingSales': 48000,
#    'grossNewSales': 1965,
#    'currentMYNetSales': 1965,
#    'currentMYTotalCommitment': 90965,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5570,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 93522,
#    'grossNewSales': 522,
#    'currentMYNetSales': 522,
#    'currentMYTotalCommitment': 93522,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5590,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5600,
#    'weeklyExports': 84500,
#    'accumulatedExports': 84500,
#    'outstandingSales': 133500,
#    'grossNewSales': 8320,
#    'currentMYNetSales': -65500,
#    'currentMYTotalCommitment': 218000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5650,
#    'weeklyExports': 65906,
#    'accumulatedExports': 65906,
#    'outstandingSales': 677000,
#    'grossNewSales': 5906,
#    'currentMYNetSales': 5906,
#    'currentMYTotalCommitment': 742906,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5700,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5800,
#    'weeklyExports': 0,
#    'accumulatedExports': 37733,
#    'outstandingSales': 262591,
#    'grossNewSales': 14356,
#    'currentMYNetSales': -6500,
#    'currentMYTotalCommitment': 300324,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5820,
#    'weeklyExports': 265,
#    'accumulatedExports': 265,
#    'outstandingSales': 270,
#    'grossNewSales': 0,
#    'currentMYNetSales': -5,
#    'currentMYTotalCommitment': 535,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5830,
#    'weeklyExports': 0,
#    'accumulatedExports': 56680,
#    'outstandingSales': 187768,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 244448,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5880,
#    'weeklyExports': 0,
#    'accumulatedExports': 46393,
#    'outstandingSales': 516803,
#    'grossNewSales': 38660,
#    'currentMYNetSales': 38660,
#    'currentMYTotalCommitment': 563196,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 6020,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 7140,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 7210,
#    'weeklyExports': 29860,
#    'accumulatedExports': 52960,
#    'outstandingSales': 291000,
#    'grossNewSales': 0,
#    'currentMYNetSales': 59860,
#    'currentMYTotalCommitment': 343960,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 7290,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 20000,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 20000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 7490,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 7530,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 481270,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 481270,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 7650,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 7910,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 835675,
#    'grossNewSales': 32600,
#    'currentMYNetSales': -83900,
#    'currentMYTotalCommitment': 835675,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-13T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 1220,
#    'weeklyExports': 276,
#    'accumulatedExports': 675,
#    'outstandingSales': 18429,
#    'grossNewSales': 20,
#    'currentMYNetSales': 20,
#    'currentMYTotalCommitment': 19104,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2010,
#    'weeklyExports': 19040,
#    'accumulatedExports': 152123,
#    'outstandingSales': 689108,
#    'grossNewSales': 49753,
#    'currentMYNetSales': 48963,
#    'currentMYTotalCommitment': 841231,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2050,
#    'weeklyExports': 64628,
#    'accumulatedExports': 67928,
#    'outstandingSales': 69978,
#    'grossNewSales': 67600,
#    'currentMYNetSales': 88306,
#    'currentMYTotalCommitment': 137906,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2080,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 4500,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 4500,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2110,
#    'weeklyExports': 32000,
#    'accumulatedExports': 38600,
#    'outstandingSales': 77399,
#    'grossNewSales': 65101,
#    'currentMYNetSales': 71099,
#    'currentMYTotalCommitment': 115999,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2150,
#    'weeklyExports': 4916,
#    'accumulatedExports': 14066,
#    'outstandingSales': 107223,
#    'grossNewSales': 6700,
#    'currentMYNetSales': 6116,
#    'currentMYTotalCommitment': 121289,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2190,
#    'weeklyExports': 0,
#    'accumulatedExports': 1582,
#    'outstandingSales': 5815,
#    'grossNewSales': 2050,
#    'currentMYNetSales': 2050,
#    'currentMYTotalCommitment': 7397,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2230,
#    'weeklyExports': 0,
#    'accumulatedExports': 45,
#    'outstandingSales': 35050,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 35095,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2250,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 137100,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 137100,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2410,
#    'weeklyExports': 0,
#    'accumulatedExports': 8686,
#    'outstandingSales': 40000,
#    'grossNewSales': 17000,
#    'currentMYNetSales': 17000,
#    'currentMYTotalCommitment': 48686,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2450,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2470,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 43350,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 43350,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2480,
#    'weeklyExports': 0,
#    'accumulatedExports': 500,
#    'outstandingSales': 18900,
#    'grossNewSales': 500,
#    'currentMYNetSales': 500,
#    'currentMYTotalCommitment': 19400,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2720,
#    'weeklyExports': 0,
#    'accumulatedExports': 1800,
#    'outstandingSales': 4900,
#    'grossNewSales': 1000,
#    'currentMYNetSales': 1000,
#    'currentMYTotalCommitment': 6700,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2740,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 43100,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 43100,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 2830,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 27680,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 27680,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3010,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 220123,
#    'grossNewSales': 64623,
#    'currentMYNetSales': 64623,
#    'currentMYTotalCommitment': 220123,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3070,
#    'weeklyExports': 0,
#    'accumulatedExports': 6315,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 6315,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3120,
#    'weeklyExports': 0,
#    'accumulatedExports': 6314,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 6314,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3310,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 17500,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 17500,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3330,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 78050,
#    'grossNewSales': 35000,
#    'currentMYNetSales': 35000,
#    'currentMYTotalCommitment': 78050,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3370,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 64000,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 64000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3510,
#    'weeklyExports': 0,
#    'accumulatedExports': 13939,
#    'outstandingSales': 31061,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 45000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3550,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 3570,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 4120,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 19999,
#    'grossNewSales': 12500,
#    'currentMYNetSales': 12500,
#    'currentMYTotalCommitment': 19999,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 4230,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 4270,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 4710,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 4750,
#    'weeklyExports': 0,
#    'accumulatedExports': 19446,
#    'outstandingSales': 70000,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 89446,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 4910,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5050,
#    'weeklyExports': 0,
#    'accumulatedExports': 157500,
#    'outstandingSales': 100000,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 257500,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5080,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5170,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 55000,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 55000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5200,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5210,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 58400,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 58400,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5420,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5460,
#    'weeklyExports': 1603,
#    'accumulatedExports': 1603,
#    'outstandingSales': 21229,
#    'grossNewSales': 21,
#    'currentMYNetSales': -704,
#    'currentMYTotalCommitment': 22832,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5490,
#    'weeklyExports': 97,
#    'accumulatedExports': 55097,
#    'outstandingSales': 143340,
#    'grossNewSales': 100,
#    'currentMYNetSales': 97,
#    'currentMYTotalCommitment': 198437,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5520,
#    'weeklyExports': 23100,
#    'accumulatedExports': 66065,
#    'outstandingSales': 27000,
#    'grossNewSales': 2100,
#    'currentMYNetSales': 2100,
#    'currentMYTotalCommitment': 93065,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5570,
#    'weeklyExports': 22,
#    'accumulatedExports': 22,
#    'outstandingSales': 93500,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 93522,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5590,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5600,
#    'weeklyExports': 0,
#    'accumulatedExports': 84500,
#    'outstandingSales': 153500,
#    'grossNewSales': 20000,
#    'currentMYNetSales': 20000,
#    'currentMYTotalCommitment': 238000,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5650,
#    'weeklyExports': 0,
#    'accumulatedExports': 65906,
#    'outstandingSales': 793000,
#    'grossNewSales': 116000,
#    'currentMYNetSales': 116000,
#    'currentMYTotalCommitment': 858906,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5700,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5800,
#    'weeklyExports': 190,
#    'accumulatedExports': 37923,
#    'outstandingSales': 263601,
#    'grossNewSales': 1200,
#    'currentMYNetSales': 1200,
#    'currentMYTotalCommitment': 301524,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5820,
#    'weeklyExports': 0,
#    'accumulatedExports': 265,
#    'outstandingSales': 270,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 535,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2019-06-20T00:00:00'},
#   {'commodityCode': 107,
#    'countryCode': 5830,
#    'weeklyExports': 54412,
#    'accumulatedExports': 111092,
#    'outstandingSales': 168946,
#    'grossNewSales': 300,
#    'currentMYNetSales': 35590,
# ...
#    'grossNewSales': 1418,
#    'currentMYNetSales': 677,
#    'currentMYTotalCommitment': 59127,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2010,
#    'weeklyExports': 14183,
#    'accumulatedExports': 207211,
#    'outstandingSales': 61938,
#    'grossNewSales': 5632,
#    'currentMYNetSales': 5290,
#    'currentMYTotalCommitment': 269149,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2050,
#    'weeklyExports': 189,
#    'accumulatedExports': 5199,
#    'outstandingSales': 1065,
#    'grossNewSales': 78,
#    'currentMYNetSales': 78,
#    'currentMYTotalCommitment': 6264,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2110,
#    'weeklyExports': 116,
#    'accumulatedExports': 2025,
#    'outstandingSales': 282,
#    'grossNewSales': 170,
#    'currentMYNetSales': 169,
#    'currentMYTotalCommitment': 2307,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2150,
#    'weeklyExports': 891,
#    'accumulatedExports': 8872,
#    'outstandingSales': 2993,
#    'grossNewSales': 442,
#    'currentMYNetSales': 344,
#    'currentMYTotalCommitment': 11865,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2190,
#    'weeklyExports': 35,
#    'accumulatedExports': 2737,
#    'outstandingSales': 1819,
#    'grossNewSales': 17,
#    'currentMYNetSales': 15,
#    'currentMYTotalCommitment': 4556,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2230,
#    'weeklyExports': 139,
#    'accumulatedExports': 3092,
#    'outstandingSales': 999,
#    'grossNewSales': 38,
#    'currentMYNetSales': 38,
#    'currentMYTotalCommitment': 4091,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2250,
#    'weeklyExports': 95,
#    'accumulatedExports': 958,
#    'outstandingSales': 66,
#    'grossNewSales': 21,
#    'currentMYNetSales': 20,
#    'currentMYTotalCommitment': 1024,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2320,
#    'weeklyExports': 6,
#    'accumulatedExports': 68,
#    'outstandingSales': 4,
#    'grossNewSales': 7,
#    'currentMYNetSales': 7,
#    'currentMYTotalCommitment': 72,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2360,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 807,
#    'grossNewSales': 107,
#    'currentMYNetSales': 107,
#    'currentMYTotalCommitment': 807,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2430,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 1,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 1,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2440,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2450,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 15,
#    'grossNewSales': 2,
#    'currentMYNetSales': 2,
#    'currentMYTotalCommitment': 15,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2470,
#    'weeklyExports': 179,
#    'accumulatedExports': 9868,
#    'outstandingSales': 3162,
#    'grossNewSales': 823,
#    'currentMYNetSales': 811,
#    'currentMYTotalCommitment': 13030,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2480,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2720,
#    'weeklyExports': 16,
#    'accumulatedExports': 18,
#    'outstandingSales': 0,
#    'grossNewSales': 16,
#    'currentMYNetSales': 16,
#    'currentMYTotalCommitment': 18,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2740,
#    'weeklyExports': 75,
#    'accumulatedExports': 617,
#    'outstandingSales': 25,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 642,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 2770,
#    'weeklyExports': 1,
#    'accumulatedExports': 6,
#    'outstandingSales': 35,
#    'grossNewSales': 2,
#    'currentMYNetSales': 2,
#    'currentMYTotalCommitment': 41,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 3010,
#    'weeklyExports': 1610,
#    'accumulatedExports': 25426,
#    'outstandingSales': 6644,
#    'grossNewSales': 668,
#    'currentMYNetSales': 521,
#    'currentMYTotalCommitment': 32070,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 3310,
#    'weeklyExports': 0,
#    'accumulatedExports': 10,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 10,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 3330,
#    'weeklyExports': 0,
#    'accumulatedExports': 863,
#    'outstandingSales': 298,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 1161,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 3370,
#    'weeklyExports': 369,
#    'accumulatedExports': 8629,
#    'outstandingSales': 4666,
#    'grossNewSales': 100,
#    'currentMYNetSales': -14,
#    'currentMYTotalCommitment': 13295,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 4120,
#    'weeklyExports': 19,
#    'accumulatedExports': 363,
#    'outstandingSales': 232,
#    'grossNewSales': 0,
#    'currentMYNetSales': -15,
#    'currentMYTotalCommitment': 595,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 4210,
#    'weeklyExports': 0,
#    'accumulatedExports': 24,
#    'outstandingSales': 3,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 27,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 4280,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 4330,
#    'weeklyExports': 0,
#    'accumulatedExports': 245,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 245,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 4633,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 4700,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 4794,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 4810,
#    'weeklyExports': 0,
#    'accumulatedExports': 150,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 150,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 5200,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 5250,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 1,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 1,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 5460,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 5520,
#    'weeklyExports': 299,
#    'accumulatedExports': 2516,
#    'outstandingSales': 821,
#    'grossNewSales': 29,
#    'currentMYNetSales': -9,
#    'currentMYTotalCommitment': 3337,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 5570,
#    'weeklyExports': 0,
#    'accumulatedExports': 69,
#    'outstandingSales': 24,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 93,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 5590,
#    'weeklyExports': 180,
#    'accumulatedExports': 1029,
#    'outstandingSales': 145,
#    'grossNewSales': 2,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 1174,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 5600,
#    'weeklyExports': 0,
#    'accumulatedExports': 34,
#    'outstandingSales': 19,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 53,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 5650,
#    'weeklyExports': 1156,
#    'accumulatedExports': 25368,
#    'outstandingSales': 9545,
#    'grossNewSales': 478,
#    'currentMYNetSales': 53,
#    'currentMYTotalCommitment': 34913,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 5660,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 5700,
#    'weeklyExports': 12344,
#    'accumulatedExports': 220302,
#    'outstandingSales': 57117,
#    'grossNewSales': 4646,
#    'currentMYNetSales': 3048,
#    'currentMYTotalCommitment': 277419,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 5800,
#    'weeklyExports': 2561,
#    'accumulatedExports': 50165,
#    'outstandingSales': 31246,
#    'grossNewSales': 765,
#    'currentMYNetSales': 569,
#    'currentMYTotalCommitment': 81411,
#    'nextMYOutstandingSales': 24,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 5820,
#    'weeklyExports': 94,
#    'accumulatedExports': 1572,
#    'outstandingSales': 353,
#    'grossNewSales': 22,
#    'currentMYNetSales': 14,
#    'currentMYTotalCommitment': 1925,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 5830,
#    'weeklyExports': 12,
#    'accumulatedExports': 1154,
#    'outstandingSales': 171,
#    'grossNewSales': 1,
#    'currentMYNetSales': 1,
#    'currentMYTotalCommitment': 1325,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 5880,
#    'weeklyExports': 4336,
#    'accumulatedExports': 84216,
#    'outstandingSales': 19710,
#    'grossNewSales': 3322,
#    'currentMYNetSales': 2918,
#    'currentMYTotalCommitment': 103926,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 6020,
#    'weeklyExports': 650,
#    'accumulatedExports': 18466,
#    'outstandingSales': 16831,
#    'grossNewSales': 281,
#    'currentMYNetSales': 90,
#    'currentMYTotalCommitment': 35297,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 6140,
#    'weeklyExports': 340,
#    'accumulatedExports': 2745,
#    'outstandingSales': 2854,
#    'grossNewSales': 1,
#    'currentMYNetSales': -19,
#    'currentMYTotalCommitment': 5599,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 6150,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   {'commodityCode': 1702,
#    'countryCode': 6410,
#    'weeklyExports': 0,
#    'accumulatedExports': 0,
#    'outstandingSales': 0,
#    'grossNewSales': 0,
#    'currentMYNetSales': 0,
#    'currentMYTotalCommitment': 0,
#    'nextMYOutstandingSales': 0,
#    'nextMYNetSales': 0,
#    'unitId': 1,
#    'weekEndingDate': '2021-05-06T00:00:00'},
#   ...]]

# %%
pd.DataFrame(all_data)
# Out:
#                                                 0     \
# 0  {'commodityCode': 107, 'countryCode': 1220, 'w...
# 1  {'commodityCode': 601, 'countryCode': 2010, 'w...
# 2  {'commodityCode': 1701, 'countryCode': 1220, '...
# 3  {'commodityCode': 1702, 'countryCode': 1220, '...
# 4  {'commodityCode': 107, 'countryCode': 1220, 'w...
# 5  {'commodityCode': 601, 'countryCode': 2010, 'w...
# 6  {'commodityCode': 1701, 'countryCode': 1220, '...
# 7  {'commodityCode': 1702, 'countryCode': 1220, '...
#
#                                                 1     \
# 0  {'commodityCode': 107, 'countryCode': 2010, 'w...
# 1  {'commodityCode': 601, 'countryCode': 2, 'week...
# 2  {'commodityCode': 1701, 'countryCode': 2010, '...
# 3  {'commodityCode': 1702, 'countryCode': 2010, '...
# 4  {'commodityCode': 107, 'countryCode': 2010, 'w...
# 5  {'commodityCode': 601, 'countryCode': 2, 'week...
# 6  {'commodityCode': 1701, 'countryCode': 2010, '...
# 7  {'commodityCode': 1702, 'countryCode': 2010, '...
#
#                                                 2     \
# 0  {'commodityCode': 107, 'countryCode': 2050, 'w...
# 1  {'commodityCode': 601, 'countryCode': 2010, 'w...
# 2  {'commodityCode': 1701, 'countryCode': 2050, '...
# 3  {'commodityCode': 1702, 'countryCode': 2050, '...
# 4  {'commodityCode': 107, 'countryCode': 2050, 'w...
# 5  {'commodityCode': 601, 'countryCode': 2010, 'w...
# 6  {'commodityCode': 1701, 'countryCode': 2050, '...
# 7  {'commodityCode': 1702, 'countryCode': 2050, '...
#
#                                                 3     \
# 0  {'commodityCode': 107, 'countryCode': 2110, 'w...
# 1  {'commodityCode': 601, 'countryCode': 2, 'week...
# 2  {'commodityCode': 1701, 'countryCode': 2150, '...
# 3  {'commodityCode': 1702, 'countryCode': 2110, '...
# 4  {'commodityCode': 107, 'countryCode': 2080, 'w...
# 5  {'commodityCode': 601, 'countryCode': 2, 'week...
# 6  {'commodityCode': 1701, 'countryCode': 2110, '...
# 7  {'commodityCode': 1702, 'countryCode': 2110, '...
#
#                                                 4     \
# 0  {'commodityCode': 107, 'countryCode': 2150, 'w...
# 1  {'commodityCode': 601, 'countryCode': 2010, 'w...
# 2  {'commodityCode': 1701, 'countryCode': 2230, '...
# 3  {'commodityCode': 1702, 'countryCode': 2150, '...
# 4  {'commodityCode': 107, 'countryCode': 2110, 'w...
# 5  {'commodityCode': 601, 'countryCode': 2010, 'w...
# 6  {'commodityCode': 1701, 'countryCode': 2150, '...
# 7  {'commodityCode': 1702, 'countryCode': 2150, '...
#
#                                                 5     \
# 0  {'commodityCode': 107, 'countryCode': 2190, 'w...
# 1  {'commodityCode': 601, 'countryCode': 2, 'week...
# 2  {'commodityCode': 1701, 'countryCode': 2250, '...
# 3  {'commodityCode': 1702, 'countryCode': 2190, '...
# 4  {'commodityCode': 107, 'countryCode': 2150, 'w...
# 5  {'commodityCode': 601, 'countryCode': 2, 'week...
# 6  {'commodityCode': 1701, 'countryCode': 2230, '...
# 7  {'commodityCode': 1702, 'countryCode': 2190, '...
#
#                                                 6     \
# 0  {'commodityCode': 107, 'countryCode': 2230, 'w...
# 1  {'commodityCode': 601, 'countryCode': 2010, 'w...
# 2  {'commodityCode': 1701, 'countryCode': 2360, '...
# 3  {'commodityCode': 1702, 'countryCode': 2230, '...
# 4  {'commodityCode': 107, 'countryCode': 2190, 'w...
# 5  {'commodityCode': 601, 'countryCode': 2010, 'w...
# 6  {'commodityCode': 1701, 'countryCode': 2250, '...
# 7  {'commodityCode': 1702, 'countryCode': 2230, '...
#
#                                                 7     \
# 0  {'commodityCode': 107, 'countryCode': 2250, 'w...
# 1  {'commodityCode': 601, 'countryCode': 2, 'week...
# 2  {'commodityCode': 1701, 'countryCode': 2410, '...
# 3  {'commodityCode': 1702, 'countryCode': 2250, '...
# 4  {'commodityCode': 107, 'countryCode': 2230, 'w...
# 5  {'commodityCode': 601, 'countryCode': 2, 'week...
# 6  {'commodityCode': 1701, 'countryCode': 2320, '...
# 7  {'commodityCode': 1702, 'countryCode': 2250, '...
#
#                                                 8     \
# 0  {'commodityCode': 107, 'countryCode': 2410, 'w...
# 1  {'commodityCode': 601, 'countryCode': 2010, 'w...
# 2  {'commodityCode': 1701, 'countryCode': 2430, '...
# 3  {'commodityCode': 1702, 'countryCode': 2470, '...
# 4  {'commodityCode': 107, 'countryCode': 2250, 'w...
# 5  {'commodityCode': 601, 'countryCode': 2010, 'w...
# 6  {'commodityCode': 1701, 'countryCode': 2360, '...
# 7  {'commodityCode': 1702, 'countryCode': 2320, '...
#
#                                                 9     ...  \
# 0  {'commodityCode': 107, 'countryCode': 2470, 'w...  ...
# 1  {'commodityCode': 601, 'countryCode': 2, 'week...  ...
# 2  {'commodityCode': 1701, 'countryCode': 2470, '...  ...
# 3  {'commodityCode': 1702, 'countryCode': 2480, '...  ...
# 4  {'commodityCode': 107, 'countryCode': 2410, 'w...  ...
# 5  {'commodityCode': 601, 'countryCode': 2, 'week...  ...
# 6  {'commodityCode': 1701, 'countryCode': 2410, '...  ...
# 7  {'commodityCode': 1702, 'countryCode': 2360, '...  ...
#
#                                                 4076  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  {'commodityCode': 1701, 'countryCode': 7290, '...
# 7                                               None
#
#                                                 4077  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  {'commodityCode': 1701, 'countryCode': 7490, '...
# 7                                               None
#
#                                                 4078  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  {'commodityCode': 1701, 'countryCode': 7620, '...
# 7                                               None
#
#                                                 4079  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  {'commodityCode': 1701, 'countryCode': 7660, '...
# 7                                               None
#
#                                                 4080  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  {'commodityCode': 1701, 'countryCode': 7910, '...
# 7                                               None
#
#                                                 4081  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  {'commodityCode': 1701, 'countryCode': 9110, '...
# 7                                               None
#
#                                                 4082  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  {'commodityCode': 1701, 'countryCode': 9350, '...
# 7                                               None
#
#                                                 4083  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  {'commodityCode': 1701, 'countryCode': 9510, '...
# 7                                               None
#
#                                                 4084  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  {'commodityCode': 1701, 'countryCode': 9610, '...
# 7                                               None
#
#                                                 4085
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  {'commodityCode': 1701, 'countryCode': 2, 'wee...
# 7                                               None
#
# [8 rows x 4086 columns]

# %%
response.json()
# Out:
# [{'commodityCode': 1702,
#   'countryCode': 1220,
#   'weeklyExports': 1476,
#   'accumulatedExports': 1476,
#   'outstandingSales': 20212,
#   'grossNewSales': 1990,
#   'currentMYNetSales': 1670,
#   'currentMYTotalCommitment': 21688,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2010,
#   'weeklyExports': 6920,
#   'accumulatedExports': 6920,
#   'outstandingSales': 99185,
#   'grossNewSales': 7249,
#   'currentMYNetSales': 6569,
#   'currentMYTotalCommitment': 106105,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2050,
#   'weeklyExports': 182,
#   'accumulatedExports': 182,
#   'outstandingSales': 2697,
#   'grossNewSales': 270,
#   'currentMYNetSales': 190,
#   'currentMYTotalCommitment': 2879,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2110,
#   'weeklyExports': 56,
#   'accumulatedExports': 56,
#   'outstandingSales': 2620,
#   'grossNewSales': 63,
#   'currentMYNetSales': 63,
#   'currentMYTotalCommitment': 2676,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2150,
#   'weeklyExports': 295,
#   'accumulatedExports': 295,
#   'outstandingSales': 2855,
#   'grossNewSales': 735,
#   'currentMYNetSales': 675,
#   'currentMYTotalCommitment': 3150,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2190,
#   'weeklyExports': 56,
#   'accumulatedExports': 56,
#   'outstandingSales': 598,
#   'grossNewSales': 18,
#   'currentMYNetSales': -20,
#   'currentMYTotalCommitment': 654,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2230,
#   'weeklyExports': 73,
#   'accumulatedExports': 73,
#   'outstandingSales': 1345,
#   'grossNewSales': 178,
#   'currentMYNetSales': 211,
#   'currentMYTotalCommitment': 1418,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2250,
#   'weeklyExports': 92,
#   'accumulatedExports': 92,
#   'outstandingSales': 507,
#   'grossNewSales': 89,
#   'currentMYNetSales': 88,
#   'currentMYTotalCommitment': 599,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2320,
#   'weeklyExports': 2,
#   'accumulatedExports': 2,
#   'outstandingSales': 2,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 4,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2360,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 492,
#   'grossNewSales': 6,
#   'currentMYNetSales': 6,
#   'currentMYTotalCommitment': 492,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2440,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2450,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 6,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 6,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2470,
#   'weeklyExports': 279,
#   'accumulatedExports': 279,
#   'outstandingSales': 5865,
#   'grossNewSales': 633,
#   'currentMYNetSales': 553,
#   'currentMYTotalCommitment': 6144,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2480,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2740,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 448,
#   'grossNewSales': 200,
#   'currentMYNetSales': 200,
#   'currentMYTotalCommitment': 448,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2770,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 34,
#   'grossNewSales': 1,
#   'currentMYNetSales': 1,
#   'currentMYTotalCommitment': 34,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3010,
#   'weeklyExports': 932,
#   'accumulatedExports': 932,
#   'outstandingSales': 14875,
#   'grossNewSales': 2442,
#   'currentMYNetSales': 2391,
#   'currentMYTotalCommitment': 15807,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3310,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3330,
#   'weeklyExports': 25,
#   'accumulatedExports': 25,
#   'outstandingSales': 242,
#   'grossNewSales': 25,
#   'currentMYNetSales': -3,
#   'currentMYTotalCommitment': 267,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3370,
#   'weeklyExports': 335,
#   'accumulatedExports': 335,
#   'outstandingSales': 6009,
#   'grossNewSales': 411,
#   'currentMYNetSales': 288,
#   'currentMYTotalCommitment': 6344,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3550,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4120,
#   'weeklyExports': 22,
#   'accumulatedExports': 22,
#   'outstandingSales': 88,
#   'grossNewSales': 16,
#   'currentMYNetSales': 16,
#   'currentMYTotalCommitment': 110,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4210,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 24,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 24,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4280,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4750,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4810,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 150,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 150,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5520,
#   'weeklyExports': 24,
#   'accumulatedExports': 24,
#   'outstandingSales': 814,
#   'grossNewSales': 229,
#   'currentMYNetSales': 202,
#   'currentMYTotalCommitment': 838,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5570,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 49,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 49,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5590,
#   'weeklyExports': 74,
#   'accumulatedExports': 74,
#   'outstandingSales': 183,
#   'grossNewSales': 33,
#   'currentMYNetSales': 32,
#   'currentMYTotalCommitment': 257,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5600,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 20,
#   'grossNewSales': 2,
#   'currentMYNetSales': 2,
#   'currentMYTotalCommitment': 20,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5650,
#   'weeklyExports': 466,
#   'accumulatedExports': 466,
#   'outstandingSales': 7492,
#   'grossNewSales': 2434,
#   'currentMYNetSales': 2406,
#   'currentMYTotalCommitment': 7958,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5660,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 1,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 1,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5700,
#   'weeklyExports': 11476,
#   'accumulatedExports': 11476,
#   'outstandingSales': 89307,
#   'grossNewSales': 2514,
#   'currentMYNetSales': 1565,
#   'currentMYTotalCommitment': 100783,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5800,
#   'weeklyExports': 2286,
#   'accumulatedExports': 2286,
#   'outstandingSales': 30945,
#   'grossNewSales': 3777,
#   'currentMYNetSales': 3255,
#   'currentMYTotalCommitment': 33231,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5820,
#   'weeklyExports': 118,
#   'accumulatedExports': 118,
#   'outstandingSales': 382,
#   'grossNewSales': 63,
#   'currentMYNetSales': 53,
#   'currentMYTotalCommitment': 500,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5830,
#   'weeklyExports': 96,
#   'accumulatedExports': 96,
#   'outstandingSales': 341,
#   'grossNewSales': 89,
#   'currentMYNetSales': 89,
#   'currentMYTotalCommitment': 437,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5880,
#   'weeklyExports': 3340,
#   'accumulatedExports': 3340,
#   'outstandingSales': 25045,
#   'grossNewSales': 3577,
#   'currentMYNetSales': 3408,
#   'currentMYTotalCommitment': 28385,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6020,
#   'weeklyExports': 1188,
#   'accumulatedExports': 1188,
#   'outstandingSales': 23408,
#   'grossNewSales': 270,
#   'currentMYNetSales': -96,
#   'currentMYTotalCommitment': 24596,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6140,
#   'weeklyExports': 169,
#   'accumulatedExports': 169,
#   'outstandingSales': 2521,
#   'grossNewSales': 33,
#   'currentMYNetSales': -37,
#   'currentMYTotalCommitment': 2690,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6150,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6410,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6820,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6860,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 7550,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 7620,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 7650,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 9110,
#   'weeklyExports': 2,
#   'accumulatedExports': 2,
#   'outstandingSales': 7,
#   'grossNewSales': 4,
#   'currentMYNetSales': 4,
#   'currentMYTotalCommitment': 9,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 9350,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 9610,
#   'weeklyExports': 24,
#   'accumulatedExports': 24,
#   'outstandingSales': 180,
#   'grossNewSales': 1,
#   'currentMYNetSales': 1,
#   'currentMYTotalCommitment': 204,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-07T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 1220,
#   'weeklyExports': 1900,
#   'accumulatedExports': 3376,
#   'outstandingSales': 23324,
#   'grossNewSales': 5406,
#   'currentMYNetSales': 5012,
#   'currentMYTotalCommitment': 26700,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2010,
#   'weeklyExports': 13312,
#   'accumulatedExports': 20232,
#   'outstandingSales': 99100,
#   'grossNewSales': 14065,
#   'currentMYNetSales': 13227,
#   'currentMYTotalCommitment': 119332,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2050,
#   'weeklyExports': 551,
#   'accumulatedExports': 733,
#   'outstandingSales': 2743,
#   'grossNewSales': 608,
#   'currentMYNetSales': 597,
#   'currentMYTotalCommitment': 3476,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2110,
#   'weeklyExports': 92,
#   'accumulatedExports': 148,
#   'outstandingSales': 2436,
#   'grossNewSales': 151,
#   'currentMYNetSales': -92,
#   'currentMYTotalCommitment': 2584,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2150,
#   'weeklyExports': 480,
#   'accumulatedExports': 775,
#   'outstandingSales': 3168,
#   'grossNewSales': 780,
#   'currentMYNetSales': 793,
#   'currentMYTotalCommitment': 3943,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2190,
#   'weeklyExports': 110,
#   'accumulatedExports': 166,
#   'outstandingSales': 687,
#   'grossNewSales': 208,
#   'currentMYNetSales': 199,
#   'currentMYTotalCommitment': 853,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2230,
#   'weeklyExports': 131,
#   'accumulatedExports': 204,
#   'outstandingSales': 1360,
#   'grossNewSales': 157,
#   'currentMYNetSales': 146,
#   'currentMYTotalCommitment': 1564,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2250,
#   'weeklyExports': 124,
#   'accumulatedExports': 216,
#   'outstandingSales': 453,
#   'grossNewSales': 73,
#   'currentMYNetSales': 70,
#   'currentMYTotalCommitment': 669,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2320,
#   'weeklyExports': 2,
#   'accumulatedExports': 4,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 4,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2360,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 492,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 492,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2450,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 6,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 6,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2470,
#   'weeklyExports': 548,
#   'accumulatedExports': 827,
#   'outstandingSales': 6170,
#   'grossNewSales': 873,
#   'currentMYNetSales': 853,
#   'currentMYTotalCommitment': 6997,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2740,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 448,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 448,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2770,
#   'weeklyExports': 1,
#   'accumulatedExports': 1,
#   'outstandingSales': 33,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 34,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3010,
#   'weeklyExports': 1116,
#   'accumulatedExports': 2048,
#   'outstandingSales': 15277,
#   'grossNewSales': 1630,
#   'currentMYNetSales': 1518,
#   'currentMYTotalCommitment': 17325,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3310,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 10,
#   'grossNewSales': 10,
#   'currentMYNetSales': 10,
#   'currentMYTotalCommitment': 10,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3330,
#   'weeklyExports': 0,
#   'accumulatedExports': 25,
#   'outstandingSales': 238,
#   'grossNewSales': 0,
#   'currentMYNetSales': -4,
#   'currentMYTotalCommitment': 263,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3370,
#   'weeklyExports': 434,
#   'accumulatedExports': 769,
#   'outstandingSales': 5657,
#   'grossNewSales': 215,
#   'currentMYNetSales': 82,
#   'currentMYTotalCommitment': 6426,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3550,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4120,
#   'weeklyExports': 22,
#   'accumulatedExports': 44,
#   'outstandingSales': 69,
#   'grossNewSales': 3,
#   'currentMYNetSales': 3,
#   'currentMYTotalCommitment': 113,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4210,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 24,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 24,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4280,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4330,
#   'weeklyExports': 25,
#   'accumulatedExports': 25,
#   'outstandingSales': 0,
#   'grossNewSales': 25,
#   'currentMYNetSales': 25,
#   'currentMYTotalCommitment': 25,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4633,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4700,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4750,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4794,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4810,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 150,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 150,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5520,
#   'weeklyExports': 215,
#   'accumulatedExports': 239,
#   'outstandingSales': 890,
#   'grossNewSales': 291,
#   'currentMYNetSales': 291,
#   'currentMYTotalCommitment': 1129,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5570,
#   'weeklyExports': 24,
#   'accumulatedExports': 24,
#   'outstandingSales': 25,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 49,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5590,
#   'weeklyExports': 26,
#   'accumulatedExports': 100,
#   'outstandingSales': 239,
#   'grossNewSales': 88,
#   'currentMYNetSales': 82,
#   'currentMYTotalCommitment': 339,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5600,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 20,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 20,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5650,
#   'weeklyExports': 671,
#   'accumulatedExports': 1137,
#   'outstandingSales': 11364,
#   'grossNewSales': 5343,
#   'currentMYNetSales': 4543,
#   'currentMYTotalCommitment': 12501,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5660,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 1,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 1,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5700,
#   'weeklyExports': 10639,
#   'accumulatedExports': 22115,
#   'outstandingSales': 88413,
#   'grossNewSales': 10888,
#   'currentMYNetSales': 9745,
#   'currentMYTotalCommitment': 110528,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5800,
#   'weeklyExports': 3911,
#   'accumulatedExports': 6197,
#   'outstandingSales': 30599,
#   'grossNewSales': 4235,
#   'currentMYNetSales': 3565,
#   'currentMYTotalCommitment': 36796,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5820,
#   'weeklyExports': 152,
#   'accumulatedExports': 270,
#   'outstandingSales': 348,
#   'grossNewSales': 129,
#   'currentMYNetSales': 118,
#   'currentMYTotalCommitment': 618,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5830,
#   'weeklyExports': 41,
#   'accumulatedExports': 137,
#   'outstandingSales': 371,
#   'grossNewSales': 71,
#   'currentMYNetSales': 71,
#   'currentMYTotalCommitment': 508,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5880,
#   'weeklyExports': 4978,
#   'accumulatedExports': 8318,
#   'outstandingSales': 24234,
#   'grossNewSales': 4238,
#   'currentMYNetSales': 4167,
#   'currentMYTotalCommitment': 32552,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6020,
#   'weeklyExports': 1217,
#   'accumulatedExports': 2405,
#   'outstandingSales': 22118,
#   'grossNewSales': 176,
#   'currentMYNetSales': -73,
#   'currentMYTotalCommitment': 24523,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6140,
#   'weeklyExports': 46,
#   'accumulatedExports': 215,
#   'outstandingSales': 2578,
#   'grossNewSales': 147,
#   'currentMYNetSales': 103,
#   'currentMYTotalCommitment': 2793,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6150,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6410,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6820,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6860,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 7550,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 99,
#   'grossNewSales': 99,
#   'currentMYNetSales': 99,
#   'currentMYTotalCommitment': 99,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 7620,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 7650,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 9110,
#   'weeklyExports': 3,
#   'accumulatedExports': 5,
#   'outstandingSales': 8,
#   'grossNewSales': 4,
#   'currentMYNetSales': 4,
#   'currentMYTotalCommitment': 13,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 9350,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 18,
#   'grossNewSales': 18,
#   'currentMYNetSales': 18,
#   'currentMYTotalCommitment': 18,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 9610,
#   'weeklyExports': 0,
#   'accumulatedExports': 24,
#   'outstandingSales': 180,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 204,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-14T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 1220,
#   'weeklyExports': 2114,
#   'accumulatedExports': 5490,
#   'outstandingSales': 22443,
#   'grossNewSales': 2760,
#   'currentMYNetSales': 1233,
#   'currentMYTotalCommitment': 27933,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2010,
#   'weeklyExports': 11872,
#   'accumulatedExports': 32104,
#   'outstandingSales': 106088,
#   'grossNewSales': 19947,
#   'currentMYNetSales': 18860,
#   'currentMYTotalCommitment': 138192,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2050,
#   'weeklyExports': 350,
#   'accumulatedExports': 1083,
#   'outstandingSales': 2491,
#   'grossNewSales': 84,
#   'currentMYNetSales': 98,
#   'currentMYTotalCommitment': 3574,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2110,
#   'weeklyExports': 55,
#   'accumulatedExports': 203,
#   'outstandingSales': 2116,
#   'grossNewSales': 20,
#   'currentMYNetSales': -265,
#   'currentMYTotalCommitment': 2319,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2150,
#   'weeklyExports': 466,
#   'accumulatedExports': 1241,
#   'outstandingSales': 3729,
#   'grossNewSales': 1092,
#   'currentMYNetSales': 1027,
#   'currentMYTotalCommitment': 4970,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2190,
#   'weeklyExports': 147,
#   'accumulatedExports': 313,
#   'outstandingSales': 575,
#   'grossNewSales': 40,
#   'currentMYNetSales': 35,
#   'currentMYTotalCommitment': 888,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2230,
#   'weeklyExports': 99,
#   'accumulatedExports': 303,
#   'outstandingSales': 1613,
#   'grossNewSales': 353,
#   'currentMYNetSales': 352,
#   'currentMYTotalCommitment': 1916,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2250,
#   'weeklyExports': 0,
#   'accumulatedExports': 216,
#   'outstandingSales': 453,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 669,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2320,
#   'weeklyExports': 2,
#   'accumulatedExports': 6,
#   'outstandingSales': 2,
#   'grossNewSales': 4,
#   'currentMYNetSales': 4,
#   'currentMYTotalCommitment': 8,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2360,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 492,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 492,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2450,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 6,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 6,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2470,
#   'weeklyExports': 701,
#   'accumulatedExports': 1528,
#   'outstandingSales': 6060,
#   'grossNewSales': 641,
#   'currentMYNetSales': 591,
#   'currentMYTotalCommitment': 7588,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2740,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 467,
#   'grossNewSales': 19,
#   'currentMYNetSales': 19,
#   'currentMYTotalCommitment': 467,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2770,
#   'weeklyExports': 0,
#   'accumulatedExports': 1,
#   'outstandingSales': 34,
#   'grossNewSales': 1,
#   'currentMYNetSales': 1,
#   'currentMYTotalCommitment': 35,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3010,
#   'weeklyExports': 1089,
#   'accumulatedExports': 3137,
#   'outstandingSales': 16578,
#   'grossNewSales': 2455,
#   'currentMYNetSales': 2390,
#   'currentMYTotalCommitment': 19715,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3310,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 10,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 10,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3330,
#   'weeklyExports': 0,
#   'accumulatedExports': 25,
#   'outstandingSales': 238,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 263,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3370,
#   'weeklyExports': 644,
#   'accumulatedExports': 1413,
#   'outstandingSales': 5250,
#   'grossNewSales': 351,
#   'currentMYNetSales': 237,
#   'currentMYTotalCommitment': 6663,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3550,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4120,
#   'weeklyExports': 12,
#   'accumulatedExports': 56,
#   'outstandingSales': 115,
#   'grossNewSales': 58,
#   'currentMYNetSales': 58,
#   'currentMYTotalCommitment': 171,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4210,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 24,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 24,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4280,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4330,
#   'weeklyExports': 74,
#   'accumulatedExports': 99,
#   'outstandingSales': 25,
#   'grossNewSales': 99,
#   'currentMYNetSales': 99,
#   'currentMYTotalCommitment': 124,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4633,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4700,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4750,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4794,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4810,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 150,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 150,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5520,
#   'weeklyExports': 148,
#   'accumulatedExports': 387,
#   'outstandingSales': 1197,
#   'grossNewSales': 461,
#   'currentMYNetSales': 455,
#   'currentMYTotalCommitment': 1584,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5550,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5570,
#   'weeklyExports': 0,
#   'accumulatedExports': 24,
#   'outstandingSales': 25,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 49,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5590,
#   'weeklyExports': 16,
#   'accumulatedExports': 116,
#   'outstandingSales': 329,
#   'grossNewSales': 108,
#   'currentMYNetSales': 106,
#   'currentMYTotalCommitment': 445,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5600,
#   'weeklyExports': 17,
#   'accumulatedExports': 17,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': -3,
#   'currentMYTotalCommitment': 17,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5650,
#   'weeklyExports': 535,
#   'accumulatedExports': 1672,
#   'outstandingSales': 16877,
#   'grossNewSales': 6199,
#   'currentMYNetSales': 6048,
#   'currentMYTotalCommitment': 18549,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5660,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': -1,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5700,
#   'weeklyExports': 12537,
#   'accumulatedExports': 34652,
#   'outstandingSales': 89792,
#   'grossNewSales': 14936,
#   'currentMYNetSales': 13916,
#   'currentMYTotalCommitment': 124444,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5800,
#   'weeklyExports': 2583,
#   'accumulatedExports': 8780,
#   'outstandingSales': 31131,
#   'grossNewSales': 3690,
#   'currentMYNetSales': 3115,
#   'currentMYTotalCommitment': 39911,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5820,
#   'weeklyExports': 145,
#   'accumulatedExports': 415,
#   'outstandingSales': 293,
#   'grossNewSales': 116,
#   'currentMYNetSales': 90,
#   'currentMYTotalCommitment': 708,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5830,
#   'weeklyExports': 83,
#   'accumulatedExports': 220,
#   'outstandingSales': 524,
#   'grossNewSales': 236,
#   'currentMYNetSales': 236,
#   'currentMYTotalCommitment': 744,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5880,
#   'weeklyExports': 4567,
#   'accumulatedExports': 12885,
#   'outstandingSales': 23791,
#   'grossNewSales': 4175,
#   'currentMYNetSales': 4124,
#   'currentMYTotalCommitment': 36676,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6020,
#   'weeklyExports': 1229,
#   'accumulatedExports': 3634,
#   'outstandingSales': 20915,
#   'grossNewSales': 164,
#   'currentMYNetSales': 26,
#   'currentMYTotalCommitment': 24549,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6140,
#   'weeklyExports': 114,
#   'accumulatedExports': 329,
#   'outstandingSales': 2448,
#   'grossNewSales': 33,
#   'currentMYNetSales': -16,
#   'currentMYTotalCommitment': 2777,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6150,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6410,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6820,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6860,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-01-21T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 7550,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 114,
# ...
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-04-29T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 25,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 25,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-04-29T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 1220,
#   'weeklyExports': 1960,
#   'accumulatedExports': 34222,
#   'outstandingSales': 24905,
#   'grossNewSales': 1418,
#   'currentMYNetSales': 677,
#   'currentMYTotalCommitment': 59127,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2010,
#   'weeklyExports': 14183,
#   'accumulatedExports': 207211,
#   'outstandingSales': 61938,
#   'grossNewSales': 5632,
#   'currentMYNetSales': 5290,
#   'currentMYTotalCommitment': 269149,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2050,
#   'weeklyExports': 189,
#   'accumulatedExports': 5199,
#   'outstandingSales': 1065,
#   'grossNewSales': 78,
#   'currentMYNetSales': 78,
#   'currentMYTotalCommitment': 6264,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2110,
#   'weeklyExports': 116,
#   'accumulatedExports': 2025,
#   'outstandingSales': 282,
#   'grossNewSales': 170,
#   'currentMYNetSales': 169,
#   'currentMYTotalCommitment': 2307,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2150,
#   'weeklyExports': 891,
#   'accumulatedExports': 8872,
#   'outstandingSales': 2993,
#   'grossNewSales': 442,
#   'currentMYNetSales': 344,
#   'currentMYTotalCommitment': 11865,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2190,
#   'weeklyExports': 35,
#   'accumulatedExports': 2737,
#   'outstandingSales': 1819,
#   'grossNewSales': 17,
#   'currentMYNetSales': 15,
#   'currentMYTotalCommitment': 4556,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2230,
#   'weeklyExports': 139,
#   'accumulatedExports': 3092,
#   'outstandingSales': 999,
#   'grossNewSales': 38,
#   'currentMYNetSales': 38,
#   'currentMYTotalCommitment': 4091,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2250,
#   'weeklyExports': 95,
#   'accumulatedExports': 958,
#   'outstandingSales': 66,
#   'grossNewSales': 21,
#   'currentMYNetSales': 20,
#   'currentMYTotalCommitment': 1024,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2320,
#   'weeklyExports': 6,
#   'accumulatedExports': 68,
#   'outstandingSales': 4,
#   'grossNewSales': 7,
#   'currentMYNetSales': 7,
#   'currentMYTotalCommitment': 72,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2360,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 807,
#   'grossNewSales': 107,
#   'currentMYNetSales': 107,
#   'currentMYTotalCommitment': 807,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2430,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 1,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 1,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2440,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2450,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 15,
#   'grossNewSales': 2,
#   'currentMYNetSales': 2,
#   'currentMYTotalCommitment': 15,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2470,
#   'weeklyExports': 179,
#   'accumulatedExports': 9868,
#   'outstandingSales': 3162,
#   'grossNewSales': 823,
#   'currentMYNetSales': 811,
#   'currentMYTotalCommitment': 13030,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2480,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2720,
#   'weeklyExports': 16,
#   'accumulatedExports': 18,
#   'outstandingSales': 0,
#   'grossNewSales': 16,
#   'currentMYNetSales': 16,
#   'currentMYTotalCommitment': 18,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2740,
#   'weeklyExports': 75,
#   'accumulatedExports': 617,
#   'outstandingSales': 25,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 642,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 2770,
#   'weeklyExports': 1,
#   'accumulatedExports': 6,
#   'outstandingSales': 35,
#   'grossNewSales': 2,
#   'currentMYNetSales': 2,
#   'currentMYTotalCommitment': 41,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3010,
#   'weeklyExports': 1610,
#   'accumulatedExports': 25426,
#   'outstandingSales': 6644,
#   'grossNewSales': 668,
#   'currentMYNetSales': 521,
#   'currentMYTotalCommitment': 32070,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3310,
#   'weeklyExports': 0,
#   'accumulatedExports': 10,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 10,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3330,
#   'weeklyExports': 0,
#   'accumulatedExports': 863,
#   'outstandingSales': 298,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 1161,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 3370,
#   'weeklyExports': 369,
#   'accumulatedExports': 8629,
#   'outstandingSales': 4666,
#   'grossNewSales': 100,
#   'currentMYNetSales': -14,
#   'currentMYTotalCommitment': 13295,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4120,
#   'weeklyExports': 19,
#   'accumulatedExports': 363,
#   'outstandingSales': 232,
#   'grossNewSales': 0,
#   'currentMYNetSales': -15,
#   'currentMYTotalCommitment': 595,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4210,
#   'weeklyExports': 0,
#   'accumulatedExports': 24,
#   'outstandingSales': 3,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 27,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4280,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4330,
#   'weeklyExports': 0,
#   'accumulatedExports': 245,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 245,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4633,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4700,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4794,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 4810,
#   'weeklyExports': 0,
#   'accumulatedExports': 150,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 150,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5200,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5250,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 1,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 1,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5460,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5520,
#   'weeklyExports': 299,
#   'accumulatedExports': 2516,
#   'outstandingSales': 821,
#   'grossNewSales': 29,
#   'currentMYNetSales': -9,
#   'currentMYTotalCommitment': 3337,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5570,
#   'weeklyExports': 0,
#   'accumulatedExports': 69,
#   'outstandingSales': 24,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 93,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5590,
#   'weeklyExports': 180,
#   'accumulatedExports': 1029,
#   'outstandingSales': 145,
#   'grossNewSales': 2,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 1174,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5600,
#   'weeklyExports': 0,
#   'accumulatedExports': 34,
#   'outstandingSales': 19,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 53,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5650,
#   'weeklyExports': 1156,
#   'accumulatedExports': 25368,
#   'outstandingSales': 9545,
#   'grossNewSales': 478,
#   'currentMYNetSales': 53,
#   'currentMYTotalCommitment': 34913,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5660,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5700,
#   'weeklyExports': 12344,
#   'accumulatedExports': 220302,
#   'outstandingSales': 57117,
#   'grossNewSales': 4646,
#   'currentMYNetSales': 3048,
#   'currentMYTotalCommitment': 277419,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5800,
#   'weeklyExports': 2561,
#   'accumulatedExports': 50165,
#   'outstandingSales': 31246,
#   'grossNewSales': 765,
#   'currentMYNetSales': 569,
#   'currentMYTotalCommitment': 81411,
#   'nextMYOutstandingSales': 24,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5820,
#   'weeklyExports': 94,
#   'accumulatedExports': 1572,
#   'outstandingSales': 353,
#   'grossNewSales': 22,
#   'currentMYNetSales': 14,
#   'currentMYTotalCommitment': 1925,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5830,
#   'weeklyExports': 12,
#   'accumulatedExports': 1154,
#   'outstandingSales': 171,
#   'grossNewSales': 1,
#   'currentMYNetSales': 1,
#   'currentMYTotalCommitment': 1325,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 5880,
#   'weeklyExports': 4336,
#   'accumulatedExports': 84216,
#   'outstandingSales': 19710,
#   'grossNewSales': 3322,
#   'currentMYNetSales': 2918,
#   'currentMYTotalCommitment': 103926,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6020,
#   'weeklyExports': 650,
#   'accumulatedExports': 18466,
#   'outstandingSales': 16831,
#   'grossNewSales': 281,
#   'currentMYNetSales': 90,
#   'currentMYTotalCommitment': 35297,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6140,
#   'weeklyExports': 340,
#   'accumulatedExports': 2745,
#   'outstandingSales': 2854,
#   'grossNewSales': 1,
#   'currentMYNetSales': -19,
#   'currentMYTotalCommitment': 5599,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6150,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  {'commodityCode': 1702,
#   'countryCode': 6410,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2021-05-06T00:00:00'},
#  ...]

# %%
headers = {
    'accept': 'application/json',
    'X-Api-Key': 'lx8NMObcTL9PSZSCZzJyykInlqLEx5WZZKtbGITw',
}

# %%
url = "https://api.fas.usda.gov/api/esr/exports/commodityCode/601/allCountries/marketYear/2023"

# %%
response = requests.get(url = url, headers=headers)

# %%
response.json()
# Out:
# [{'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-06-09T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-06-09T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-06-16T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-06-16T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-06-23T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-06-23T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-06-30T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-06-30T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-07-07T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-07-07T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-07-14T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-07-14T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-07-21T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-07-21T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-07-28T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-07-28T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-08-04T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-08-04T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-08-11T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-08-11T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-08-18T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-08-18T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-08-25T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-08-25T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-09-01T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-09-01T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-09-08T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-09-08T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-09-15T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-09-15T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-09-22T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-09-22T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-09-29T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-09-29T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-10-06T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-10-06T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-10-13T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-10-13T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-10-20T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-10-20T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-10-27T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-10-27T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-11-03T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-11-03T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-11-10T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-11-10T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-11-17T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-11-17T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-11-24T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-11-24T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-12-01T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-12-01T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-12-08T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-12-08T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-12-15T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-12-15T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-12-22T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-12-22T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-12-29T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2022-12-29T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-01-05T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-01-05T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-01-12T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-01-12T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-01-19T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-01-19T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-01-26T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-01-26T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-02-02T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-02-02T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-02-09T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-02-09T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-02-16T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-02-16T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-02-23T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-02-23T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-03-02T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-03-02T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 1220,
#   'weeklyExports': 1645,
#   'accumulatedExports': 1645,
#   'outstandingSales': 1465,
#   'grossNewSales': 3110,
#   'currentMYNetSales': 3110,
#   'currentMYTotalCommitment': 3110,
#   'nextMYOutstandingSales': 590,
#   'nextMYNetSales': 590,
#   'unitId': 1,
#   'weekEndingDate': '2023-03-09T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-03-09T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-03-09T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 1220,
#   'weeklyExports': 0,
#   'accumulatedExports': 1645,
#   'outstandingSales': 1465,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 3110,
#   'nextMYOutstandingSales': 590,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-03-16T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-03-16T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-03-16T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 1220,
#   'weeklyExports': 0,
#   'accumulatedExports': 1645,
#   'outstandingSales': 1465,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 3110,
#   'nextMYOutstandingSales': 590,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-03-23T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-03-23T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-03-23T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 1220,
#   'weeklyExports': 0,
#   'accumulatedExports': 1645,
#   'outstandingSales': 1465,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 3110,
#   'nextMYOutstandingSales': 590,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-03-30T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-03-30T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-03-30T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 1220,
#   'weeklyExports': 0,
#   'accumulatedExports': 1645,
#   'outstandingSales': 1465,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 3110,
#   'nextMYOutstandingSales': 590,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-04-06T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-04-06T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-04-06T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 1220,
#   'weeklyExports': 0,
#   'accumulatedExports': 1645,
#   'outstandingSales': 1465,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 3110,
#   'nextMYOutstandingSales': 590,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-04-13T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-04-13T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-04-13T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 1220,
#   'weeklyExports': 0,
#   'accumulatedExports': 1645,
#   'outstandingSales': 1465,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 3110,
#   'nextMYOutstandingSales': 590,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-04-20T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 125,
#   'grossNewSales': 125,
#   'currentMYNetSales': 125,
#   'currentMYTotalCommitment': 125,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-04-20T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-04-20T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 1220,
#   'weeklyExports': 0,
#   'accumulatedExports': 1645,
#   'outstandingSales': 1465,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 3110,
#   'nextMYOutstandingSales': 590,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-04-27T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 125,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 125,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-04-27T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-04-27T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 1220,
#   'weeklyExports': 0,
#   'accumulatedExports': 1645,
#   'outstandingSales': 1465,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 3110,
#   'nextMYOutstandingSales': 590,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-05-04T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 81,
#   'accumulatedExports': 81,
#   'outstandingSales': 44,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 125,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-05-04T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-05-04T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 1220,
#   'weeklyExports': 0,
#   'accumulatedExports': 1645,
#   'outstandingSales': 1465,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 3110,
#   'nextMYOutstandingSales': 590,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-05-11T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 81,
#   'outstandingSales': 44,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 125,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-05-11T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-05-11T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 1220,
#   'weeklyExports': 0,
#   'accumulatedExports': 1645,
#   'outstandingSales': 1465,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 3110,
#   'nextMYOutstandingSales': 590,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-05-18T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 81,
#   'accumulatedExports': 162,
#   'outstandingSales': 0,
#   'grossNewSales': 41,
#   'currentMYNetSales': 37,
#   'currentMYTotalCommitment': 162,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-05-18T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-05-18T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 1220,
#   'weeklyExports': 0,
#   'accumulatedExports': 1645,
#   'outstandingSales': 1465,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 3110,
#   'nextMYOutstandingSales': 590,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-05-25T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 162,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 162,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-05-25T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-05-25T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 1220,
#   'weeklyExports': 0,
#   'accumulatedExports': 1645,
#   'outstandingSales': 1465,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 3110,
#   'nextMYOutstandingSales': 2055,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-06-01T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2010,
#   'weeklyExports': 0,
#   'accumulatedExports': 162,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 162,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-06-01T00:00:00'},
#  {'commodityCode': 601,
#   'countryCode': 2,
#   'weeklyExports': 0,
#   'accumulatedExports': 0,
#   'outstandingSales': 0,
#   'grossNewSales': 0,
#   'currentMYNetSales': 0,
#   'currentMYTotalCommitment': 0,
#   'nextMYOutstandingSales': 0,
#   'nextMYNetSales': 0,
#   'unitId': 1,
#   'weekEndingDate': '2023-06-01T00:00:00'}]

# %%
response.json()
# Out:
# [{'commodityCode': 101, 'commodityName': 'Wheat - HRW', 'unitId': 1},
#  {'commodityCode': 102, 'commodityName': 'Wheat - SRW', 'unitId': 1},
#  {'commodityCode': 103, 'commodityName': 'Wheat - HRS', 'unitId': 1},
#  {'commodityCode': 104, 'commodityName': 'Wheat - White', 'unitId': 1},
#  {'commodityCode': 105, 'commodityName': 'Wheat - Durum', 'unitId': 1},
#  {'commodityCode': 106, 'commodityName': 'Wheat - Mixed', 'unitId': 1},
#  {'commodityCode': 107, 'commodityName': 'All Wheat', 'unitId': 1},
#  {'commodityCode': 201, 'commodityName': 'Wheat Products', 'unitId': 1},
#  {'commodityCode': 301, 'commodityName': 'Barley', 'unitId': 1},
#  {'commodityCode': 401, 'commodityName': 'Corn', 'unitId': 1},
#  {'commodityCode': 501, 'commodityName': 'Rye', 'unitId': 1},
#  {'commodityCode': 601, 'commodityName': 'Oats', 'unitId': 1},
#  {'commodityCode': 701, 'commodityName': 'Sorghum', 'unitId': 1},
#  {'commodityCode': 801, 'commodityName': 'Soybeans', 'unitId': 1},
#  {'commodityCode': 901, 'commodityName': 'Soybean cake & meal', 'unitId': 1},
#  {'commodityCode': 902, 'commodityName': 'Soybean Oil', 'unitId': 1},
#  {'commodityCode': 1001, 'commodityName': 'Flaxseed', 'unitId': 1},
#  {'commodityCode': 1101, 'commodityName': 'Linseed Oil', 'unitId': 1},
#  {'commodityCode': 1110, 'commodityName': 'Sunflowerseed Oil', 'unitId': 1},
#  {'commodityCode': 1201, 'commodityName': 'Cottonseed', 'unitId': 1},
#  {'commodityCode': 1202,
#   'commodityName': 'Cottonseed cake & meal',
#   'unitId': 1},
#  {'commodityCode': 1203, 'commodityName': 'Cottonseed Oil', 'unitId': 1},
#  {'commodityCode': 1301, 'commodityName': 'Cotton- Am Pima', 'unitId': 2},
#  {'commodityCode': 1401,
#   'commodityName': 'Cotton- Upland 1 1/16" & over',
#   'unitId': 2},
#  {'commodityCode': 1402,
#   'commodityName': 'Cotton- Upland 1"-1 1/16" & over',
#   'unitId': 2},
#  {'commodityCode': 1403,
#   'commodityName': 'Cotton- Upland under 1"',
#   'unitId': 2},
#  {'commodityCode': 1404, 'commodityName': 'All Upland Cotton', 'unitId': 2},
#  {'commodityCode': 1498, 'commodityName': 'Rice - LG Rough', 'unitId': 1},
#  {'commodityCode': 1499,
#   'commodityName': 'Rice- Med, Short,Other Rough',
#   'unitId': 1},
#  {'commodityCode': 1501, 'commodityName': 'Rice- LG Brown', 'unitId': 1},
#  {'commodityCode': 1502,
#   'commodityName': 'Rice- Med,Short, Other Brown',
#   'unitId': 1},
#  {'commodityCode': 1503,
#   'commodityName': 'Rice - Long Grain, Milled',
#   'unitId': 1},
#  {'commodityCode': 1504,
#   'commodityName': 'Rice- Med,Short,Other Milled',
#   'unitId': 1},
#  {'commodityCode': 1505, 'commodityName': 'All Rice', 'unitId': 1},
#  {'commodityCode': 1601,
#   'commodityName': 'Cattle Hides - Whole - Excluding Wet Blues',
#   'unitId': 3},
#  {'commodityCode': 1602,
#   'commodityName': 'Calf Skins - Whole - Excluding Wet Blues',
#   'unitId': 3},
#  {'commodityCode': 1603,
#   'commodityName': 'Kip Skins - Whole - Excluding Wet Blues',
#   'unitId': 3},
#  {'commodityCode': 1604,
#   'commodityName': 'Cattle Hides-Cut into Croupons, etc-excl Wet Blues',
#   'unitId': 4},
#  {'commodityCode': 1605,
#   'commodityName': 'Cattle Hides and Skins-other-excluding Wet Blues',
#   'unitId': 5},
#  {'commodityCode': 1606,
#   'commodityName': 'Cattle Wet Blues-Unsplit (Whole or Sided)',
#   'unitId': 4},
#  {'commodityCode': 1607,
#   'commodityName': 'Cattle Wet Blues-Grain Splits (Whole or Sided)',
#   'unitId': 4},
#  {'commodityCode': 1608,
#   'commodityName': 'Cattle Wet Blues-Splits-Excluding Grain Splits',
#   'unitId': 5},
#  {'commodityCode': 1701,
#   'commodityName': 'Fresh, Chilled, or Frozen Muscle Cuts of Beef',
#   'unitId': 1},
#  {'commodityCode': 1702,
#   'commodityName': 'Fresh, Chilled, or Frozen Muscle Cuts of Pork',
#   'unitId': 1}]

# %%
countries_response = requests.get("https://api.fas.usda.gov/api/esr/countries", headers=headers)
countries_response.json()
# Out:
# [{'countryCode': 1,
#   'countryName': 'EUROPEAN',
#   'countryDescription': 'EUROPEAN UNION - 27           ',
#   'regionId': 1,
#   'gencCode': None},
#  {'countryCode': 2,
#   'countryName': 'UNKNOWN',
#   'countryDescription': 'UNKNOWN',
#   'regionId': 99,
#   'gencCode': 'AX1'},
#  {'countryCode': 1010,
#   'countryName': 'GREENLD ',
#   'countryDescription': 'GREENLAND                      ',
#   'regionId': 11,
#   'gencCode': 'GRL'},
#  {'countryCode': 1220,
#   'countryName': 'CANADA  ',
#   'countryDescription': 'CANADA                         ',
#   'regionId': 11,
#   'gencCode': 'CAN'},
#  {'countryCode': 1610,
#   'countryName': 'MIGUEL  ',
#   'countryDescription': 'ST. PIERRE AND MIQUELON        ',
#   'regionId': 11,
#   'gencCode': None},
#  {'countryCode': 2010,
#   'countryName': 'MEXICO  ',
#   'countryDescription': 'MEXICO                         ',
#   'regionId': 11,
#   'gencCode': 'MEX'},
#  {'countryCode': 2050,
#   'countryName': 'GUATMAL ',
#   'countryDescription': 'GUATEMALA                      ',
#   'regionId': 11,
#   'gencCode': 'GTM'},
#  {'countryCode': 2080,
#   'countryName': 'BELIZE  ',
#   'countryDescription': 'BELIZE                         ',
#   'regionId': 11,
#   'gencCode': 'BLZ'},
#  {'countryCode': 2110,
#   'countryName': 'SALVADR ',
#   'countryDescription': 'EL SALVADOR                    ',
#   'regionId': 11,
#   'gencCode': 'SLV'},
#  {'countryCode': 2150,
#   'countryName': 'HONDURA ',
#   'countryDescription': 'HONDURAS                       ',
#   'regionId': 11,
#   'gencCode': 'HND'},
#  {'countryCode': 2190,
#   'countryName': 'NICARAG ',
#   'countryDescription': 'NICARAGUA                      ',
#   'regionId': 11,
#   'gencCode': 'NIC'},
#  {'countryCode': 2230,
#   'countryName': 'C RICA  ',
#   'countryDescription': 'COSTA RICA                     ',
#   'regionId': 11,
#   'gencCode': 'CRI'},
#  {'countryCode': 2250,
#   'countryName': 'PANAMA  ',
#   'countryDescription': 'PANAMA                         ',
#   'regionId': 11,
#   'gencCode': 'PAN'},
#  {'countryCode': 2270,
#   'countryName': 'CANAL Z ',
#   'countryDescription': 'PANAMA CANAL ZONE              ',
#   'regionId': 11,
#   'gencCode': None},
#  {'countryCode': 2320,
#   'countryName': 'BERMUDA ',
#   'countryDescription': 'BERMUDA                        ',
#   'regionId': 11,
#   'gencCode': 'BMU'},
#  {'countryCode': 2360,
#   'countryName': 'BAHAMAS ',
#   'countryDescription': 'BAHAMAS, THE                   ',
#   'regionId': 11,
#   'gencCode': 'BHS'},
#  {'countryCode': 2390,
#   'countryName': 'CUBA    ',
#   'countryDescription': 'CUBA                           ',
#   'regionId': 11,
#   'gencCode': 'CUB'},
#  {'countryCode': 2410,
#   'countryName': 'JAMAICA ',
#   'countryDescription': 'JAMAICA                        ',
#   'regionId': 11,
#   'gencCode': 'JAM'},
#  {'countryCode': 2430,
#   'countryName': 'TURK IS ',
#   'countryDescription': 'TURKS AND CAICOS ISLANDS       ',
#   'regionId': 11,
#   'gencCode': 'TCA'},
#  {'countryCode': 2440,
#   'countryName': 'CAYMAN  ',
#   'countryDescription': 'CAYMAN ISLANDS                 ',
#   'regionId': 11,
#   'gencCode': 'CYM'},
#  {'countryCode': 2450,
#   'countryName': 'HAITI   ',
#   'countryDescription': 'HAITI                          ',
#   'regionId': 11,
#   'gencCode': 'HTI'},
#  {'countryCode': 2470,
#   'countryName': 'DOM REP ',
#   'countryDescription': 'DOMINICAN REPUBLIC             ',
#   'regionId': 11,
#   'gencCode': 'DOM'},
#  {'countryCode': 2480,
#   'countryName': 'LW WW I ',
#   'countryDescription': 'LEEWARD-WINDWARD ISLANDS       ',
#   'regionId': 11,
#   'gencCode': None},
#  {'countryCode': 2720,
#   'countryName': 'BARBADO ',
#   'countryDescription': 'BARBADOS                       ',
#   'regionId': 11,
#   'gencCode': 'BRB'},
#  {'countryCode': 2740,
#   'countryName': 'TRINID  ',
#   'countryDescription': 'TRINIDAD AND TOBAGO            ',
#   'regionId': 11,
#   'gencCode': 'TTO'},
#  {'countryCode': 2770,
#   'countryName': 'N ANTIL ',
#   'countryDescription': 'NETHERLANDS ANTILLES           ',
#   'regionId': 11,
#   'gencCode': None},
#  {'countryCode': 2830,
#   'countryName': 'F W IND ',
#   'countryDescription': 'FRENCH WEST INDIES             ',
#   'regionId': 11,
#   'gencCode': None},
#  {'countryCode': 3010,
#   'countryName': 'COLOMB  ',
#   'countryDescription': 'COLOMBIA                       ',
#   'regionId': 11,
#   'gencCode': 'COL'},
#  {'countryCode': 3070,
#   'countryName': 'VENEZ   ',
#   'countryDescription': 'VENEZUELA                      ',
#   'regionId': 11,
#   'gencCode': 'VEN'},
#  {'countryCode': 3120,
#   'countryName': 'GUYANA  ',
#   'countryDescription': 'GUYANA                         ',
#   'regionId': 11,
#   'gencCode': 'GUY'},
#  {'countryCode': 3150,
#   'countryName': 'SURINAM ',
#   'countryDescription': 'SURINAM                        ',
#   'regionId': 11,
#   'gencCode': None},
#  {'countryCode': 3170,
#   'countryName': 'F GUIAN ',
#   'countryDescription': 'FRENCH GUIANA                  ',
#   'regionId': 11,
#   'gencCode': 'GUF'},
#  {'countryCode': 3310,
#   'countryName': 'ECUADOR ',
#   'countryDescription': 'ECUADOR                        ',
#   'regionId': 11,
#   'gencCode': 'ECU'},
#  {'countryCode': 3330,
#   'countryName': 'PERU    ',
#   'countryDescription': 'PERU                           ',
#   'regionId': 11,
#   'gencCode': 'PER'},
#  {'countryCode': 3350,
#   'countryName': 'BOLIVIA ',
#   'countryDescription': 'BOLIVIA                        ',
#   'regionId': 11,
#   'gencCode': 'BOL'},
#  {'countryCode': 3370,
#   'countryName': 'CHILE   ',
#   'countryDescription': 'CHILE                          ',
#   'regionId': 11,
#   'gencCode': 'CHL'},
#  {'countryCode': 3510,
#   'countryName': 'BRAZIL  ',
#   'countryDescription': 'BRAZIL                         ',
#   'regionId': 11,
#   'gencCode': 'BRA'},
#  {'countryCode': 3530,
#   'countryName': 'PARAGUA ',
#   'countryDescription': 'PARAGUAY                       ',
#   'regionId': 11,
#   'gencCode': 'PRY'},
#  {'countryCode': 3550,
#   'countryName': 'URUGUAY ',
#   'countryDescription': 'URUGUAY                        ',
#   'regionId': 11,
#   'gencCode': 'URY'},
#  {'countryCode': 3570,
#   'countryName': 'ARGENT  ',
#   'countryDescription': 'ARGENTINA                      ',
#   'regionId': 11,
#   'gencCode': 'ARG'},
#  {'countryCode': 3720,
#   'countryName': 'FALK IS ',
#   'countryDescription': 'FALKLAND ISLANDS (ISLAS MALVIN)',
#   'regionId': 11,
#   'gencCode': None},
#  {'countryCode': 4000,
#   'countryName': 'ICELAND ',
#   'countryDescription': 'ICELAND                        ',
#   'regionId': 2,
#   'gencCode': 'ISL'},
#  {'countryCode': 4010,
#   'countryName': 'SWEDEN  ',
#   'countryDescription': 'SWEDEN                         ',
#   'regionId': 1,
#   'gencCode': 'SWE'},
#  {'countryCode': 4030,
#   'countryName': 'NORWAY  ',
#   'countryDescription': 'NORWAY                         ',
#   'regionId': 2,
#   'gencCode': 'NOR'},
#  {'countryCode': 4050,
#   'countryName': 'FINLAND ',
#   'countryDescription': 'FINLAND                        ',
#   'regionId': 1,
#   'gencCode': 'FIN'},
#  {'countryCode': 4090,
#   'countryName': 'DENMARK ',
#   'countryDescription': 'DENMARK                        ',
#   'regionId': 1,
#   'gencCode': 'DNK'},
#  {'countryCode': 4120,
#   'countryName': 'U KING  ',
#   'countryDescription': 'UNITED KINGDOM                 ',
#   'regionId': 1,
#   'gencCode': 'GBR'},
#  {'countryCode': 4190,
#   'countryName': 'IRELAND ',
#   'countryDescription': 'IRELAND                        ',
#   'regionId': 1,
#   'gencCode': 'IRL'},
#  {'countryCode': 4210,
#   'countryName': 'NETHLDS ',
#   'countryDescription': 'NETHERLANDS                    ',
#   'regionId': 1,
#   'gencCode': 'NLD'},
#  {'countryCode': 4230,
#   'countryName': 'BELGIUM ',
#   'countryDescription': 'BELGIUM-LUXEMBOURG             ',
#   'regionId': 1,
#   'gencCode': 'BEL'},
#  {'countryCode': 4270,
#   'countryName': 'FRANCE  ',
#   'countryDescription': 'FRANCE                         ',
#   'regionId': 1,
#   'gencCode': 'FRA'},
#  {'countryCode': 4280,
#   'countryName': 'GERMANY ',
#   'countryDescription': 'GERMANY                        ',
#   'regionId': 1,
#   'gencCode': 'DEU'},
#  {'countryCode': 4290,
#   'countryName': 'GERM DR ',
#   'countryDescription': 'GERMAN DEMOCRATIC REPUBLIC     ',
#   'regionId': 1,
#   'gencCode': None},
#  {'countryCode': 4330,
#   'countryName': 'AUSTRIA ',
#   'countryDescription': 'AUSTRIA                        ',
#   'regionId': 1,
#   'gencCode': 'AUT'},
#  {'countryCode': 4350,
#   'countryName': 'CZECHO  ',
#   'countryDescription': 'CZECHOSLOVAKIA                 ',
#   'regionId': 1,
#   'gencCode': None},
#  {'countryCode': 4351,
#   'countryName': 'CZECH RE',
#   'countryDescription': 'CZECH REPUBLIC                 ',
#   'regionId': 1,
#   'gencCode': 'CZE'},
#  {'countryCode': 4359,
#   'countryName': 'SLOVAKIA',
#   'countryDescription': 'SLOVAKIA                       ',
#   'regionId': 1,
#   'gencCode': 'SVK'},
#  {'countryCode': 4370,
#   'countryName': 'HUNGARY ',
#   'countryDescription': 'HUNGARY                        ',
#   'regionId': 1,
#   'gencCode': 'HUN'},
#  {'countryCode': 4410,
#   'countryName': 'SWITZLD ',
#   'countryDescription': 'SWITZERLAND                    ',
#   'regionId': 2,
#   'gencCode': 'CHE'},
#  {'countryCode': 4461,
#   'countryName': 'FSU-12  ',
#   'countryDescription': 'FORMER SOVIET UNION            ',
#   'regionId': 4,
#   'gencCode': None},
#  {'countryCode': 4470,
#   'countryName': 'ESTONIA ',
#   'countryDescription': 'ESTONIA                        ',
#   'regionId': 1,
#   'gencCode': 'EST'},
#  {'countryCode': 4490,
#   'countryName': 'LATVIA  ',
#   'countryDescription': 'LATVIA                         ',
#   'regionId': 1,
#   'gencCode': 'LVA'},
#  {'countryCode': 4510,
#   'countryName': 'LITHUAN ',
#   'countryDescription': 'LITHUANIA                      ',
#   'regionId': 1,
#   'gencCode': 'LTU'},
#  {'countryCode': 4550,
#   'countryName': 'POLAND  ',
#   'countryDescription': 'POLAND                         ',
#   'regionId': 1,
#   'gencCode': 'POL'},
#  {'countryCode': 4621,
#   'countryName': 'RUSSIA  ',
#   'countryDescription': 'RUSSIAN FEDERATION             ',
#   'regionId': 4,
#   'gencCode': 'RUS'},
#  {'countryCode': 4622,
#   'countryName': 'BELARUS ',
#   'countryDescription': 'BYELARUS, REPUBLIC OF          ',
#   'regionId': 4,
#   'gencCode': 'BLR'},
#  {'countryCode': 4623,
#   'countryName': 'UKRAINE ',
#   'countryDescription': 'UKRAINE                        ',
#   'regionId': 4,
#   'gencCode': 'UKR'},
#  {'countryCode': 4631,
#   'countryName': 'ARMENIA ',
#   'countryDescription': 'ARMENIA, REPUBLIC OF           ',
#   'regionId': 4,
#   'gencCode': 'ARM'},
#  {'countryCode': 4632,
#   'countryName': 'AZERBJN ',
#   'countryDescription': 'AZERBAIJAN, REPUBLIC OF        ',
#   'regionId': 4,
#   'gencCode': None},
#  {'countryCode': 4633,
#   'countryName': 'GEORGIA ',
#   'countryDescription': 'GEORGIA, REPUBLIC OF           ',
#   'regionId': 4,
#   'gencCode': 'GEO'},
#  {'countryCode': 4634,
#   'countryName': 'KAZAKHS ',
#   'countryDescription': 'KAZAKHSTAN, REPUBLIC OF        ',
#   'regionId': 4,
#   'gencCode': None},
#  {'countryCode': 4635,
#   'countryName': 'KYRGYZS ',
#   'countryDescription': 'KYRGYZSTAN, REPUBLIC OF        ',
#   'regionId': 4,
#   'gencCode': None},
#  {'countryCode': 4641,
#   'countryName': 'MOLDOVA ',
#   'countryDescription': 'MOLDOVA, REPUBLIC OF           ',
#   'regionId': 4,
#   'gencCode': 'MDA'},
#  {'countryCode': 4642,
#   'countryName': 'TAJIKIS ',
#   'countryDescription': 'TAJIKISTAN, REPUBLIC OF        ',
#   'regionId': 4,
#   'gencCode': None},
#  {'countryCode': 4643,
#   'countryName': 'TURKMEN ',
#   'countryDescription': 'TURKMENISTAN                   ',
#   'regionId': 4,
#   'gencCode': 'TKM'},
#  {'countryCode': 4644,
#   'countryName': 'UZBEKIS ',
#   'countryDescription': 'UZBEKISTAN, REPUBLIC OF        ',
#   'regionId': 4,
#   'gencCode': None},
#  {'countryCode': 4670,
#   'countryName': 'AZORES  ',
#   'countryDescription': 'AZORES                         ',
#   'regionId': 2,
#   'gencCode': None},
#  {'countryCode': 4700,
#   'countryName': 'SPAIN   ',
#   'countryDescription': 'SPAIN                          ',
#   'regionId': 1,
#   'gencCode': 'ESP'},
#  {'countryCode': 4710,
#   'countryName': 'PORTUGL ',
#   'countryDescription': 'PORTUGAL                       ',
#   'regionId': 1,
#   'gencCode': 'PRT'},
#  {'countryCode': 4720,
#   'countryName': 'GIBRALT ',
#   'countryDescription': 'GIBRALTAR                      ',
#   'regionId': 2,
#   'gencCode': 'GIB'},
#  {'countryCode': 4730,
#   'countryName': 'MALTA   ',
#   'countryDescription': 'MALTA & GOZO                   ',
#   'regionId': 1,
#   'gencCode': 'MLT'},
#  {'countryCode': 4750,
#   'countryName': 'ITALY   ',
#   'countryDescription': 'ITALY                          ',
#   'regionId': 1,
#   'gencCode': 'ITA'},
#  {'countryCode': 4791,
#   'countryName': 'CROATIA ',
#   'countryDescription': 'CROATIA                        ',
#   'regionId': 2,
#   'gencCode': 'HRV'},
#  {'countryCode': 4792,
#   'countryName': 'SLOVENIA',
#   'countryDescription': 'SLOVENIA                       ',
#   'regionId': 1,
#   'gencCode': 'SVN'},
#  {'countryCode': 4793,
#   'countryName': 'BOSNIA  ',
#   'countryDescription': 'BOSNIA-HERCEGOVINA             ',
#   'regionId': 2,
#   'gencCode': None},
#  {'countryCode': 4794,
#   'countryName': 'MACEDON ',
#   'countryDescription': 'MACEDONIA (SKOPJE)             ',
#   'regionId': 2,
#   'gencCode': None},
#  {'countryCode': 4799,
#   'countryName': 'YUGOSLV ',
#   'countryDescription': 'YUGOSLAVIA                     ',
#   'regionId': 2,
#   'gencCode': None},
#  {'countryCode': 4810,
#   'countryName': 'ALBANIA ',
#   'countryDescription': 'ALBANIA                        ',
#   'regionId': 2,
#   'gencCode': 'ALB'},
#  {'countryCode': 4840,
#   'countryName': 'GREECE  ',
#   'countryDescription': 'GREECE                         ',
#   'regionId': 1,
#   'gencCode': 'GRC'},
#  {'countryCode': 4850,
#   'countryName': 'ROMANIA ',
#   'countryDescription': 'ROMANIA                        ',
#   'regionId': 1,
#   'gencCode': 'ROU'},
#  {'countryCode': 4870,
#   'countryName': 'BULGAR  ',
#   'countryDescription': 'BULGARIA                       ',
#   'regionId': 1,
#   'gencCode': 'BGR'},
#  {'countryCode': 4890,
#   'countryName': 'TURKEY  ',
#   'countryDescription': 'TURKEY                         ',
#   'regionId': 2,
#   'gencCode': 'TUR'},
#  {'countryCode': 4910,
#   'countryName': 'CYPRUS  ',
#   'countryDescription': 'CYPRUS                         ',
#   'regionId': 1,
#   'gencCode': 'CYP'},
#  {'countryCode': 5020,
#   'countryName': 'SYRIA   ',
#   'countryDescription': 'SYRIA                          ',
#   'regionId': 9,
#   'gencCode': 'SYR'},
#  {'countryCode': 5040,
#   'countryName': 'LEBANON ',
#   'countryDescription': 'LEBANON                        ',
#   'regionId': 9,
#   'gencCode': 'LBN'},
#  {'countryCode': 5050,
#   'countryName': 'IRAQ    ',
#   'countryDescription': 'IRAQ                           ',
#   'regionId': 9,
#   'gencCode': 'IRQ'},
#  {'countryCode': 5070,
#   'countryName': 'IRAN    ',
#   'countryDescription': 'IRAN                           ',
#   'regionId': 9,
#   'gencCode': 'IRN'},
#  {'countryCode': 5080,
#   'countryName': 'ISRAEL  ',
#   'countryDescription': 'ISRAEL                         ',
#   'regionId': 9,
#   'gencCode': 'ISR'},
#  {'countryCode': 5110,
#   'countryName': 'JORDAN  ',
#   'countryDescription': 'JORDAN                         ',
#   'regionId': 9,
#   'gencCode': 'JOR'},
#  {'countryCode': 5120,
#   'countryName': 'GAZA ST ',
#   'countryDescription': 'GAZA STRIP                     ',
#   'regionId': 9,
#   'gencCode': None},
#  {'countryCode': 5130,
#   'countryName': 'KUWAIT  ',
#   'countryDescription': 'KUWAIT                         ',
#   'regionId': 9,
#   'gencCode': 'KWT'},
#  {'countryCode': 5170,
#   'countryName': 'S ARAB  ',
#   'countryDescription': 'SAUDI ARABIA                   ',
#   'regionId': 9,
#   'gencCode': 'SAU'},
#  {'countryCode': 5180,
#   'countryName': 'QATAR   ',
#   'countryDescription': 'QATAR                          ',
#   'regionId': 9,
#   'gencCode': 'QAT'},
#  {'countryCode': 5200,
#   'countryName': 'U AR EM ',
#   'countryDescription': 'UNITED ARAB EMIRATES           ',
#   'regionId': 9,
#   'gencCode': 'ARE'},
#  {'countryCode': 5210,
#   'countryName': 'YEMEN   ',
#   'countryDescription': 'YEMEN                          ',
#   'regionId': 9,
#   'gencCode': 'YEM'},
#  {'countryCode': 5220,
#   'countryName': 'S YEMEN ',
#   'countryDescription': 'YEMEN (ADEN)                   ',
#   'regionId': 9,
#   'gencCode': None},
#  {'countryCode': 5230,
#   'countryName': 'OMAN    ',
#   'countryDescription': 'OMAN                           ',
#   'regionId': 9,
#   'gencCode': 'OMN'},
#  {'countryCode': 5250,
#   'countryName': 'BAHRAIN ',
#   'countryDescription': 'BAHRAIN                        ',
#   'regionId': 9,
#   'gencCode': 'BHR'},
#  {'countryCode': 5310,
#   'countryName': 'AFGHAN  ',
#   'countryDescription': 'AFGHANISTAN                    ',
#   'regionId': 9,
#   'gencCode': 'AFG'},
#  {'countryCode': 5330,
#   'countryName': 'INDIA   ',
#   'countryDescription': 'INDIA                          ',
#   'regionId': 8,
#   'gencCode': 'IND'},
#  {'countryCode': 5350,
#   'countryName': 'PAKISTN ',
#   'countryDescription': 'PAKISTAN                       ',
#   'regionId': 9,
#   'gencCode': 'PAK'},
#  {'countryCode': 5360,
#   'countryName': 'NEPAL   ',
#   'countryDescription': 'NEPAL                          ',
#   'regionId': 9,
#   'gencCode': 'NPL'},
#  {'countryCode': 5380,
#   'countryName': 'BANGLADH',
#   'countryDescription': 'BANGLADESH                     ',
#   'regionId': 9,
#   'gencCode': 'BGD'},
#  {'countryCode': 5420,
#   'countryName': 'S LANKA ',
#   'countryDescription': 'SRI LANKA                      ',
#   'regionId': 9,
#   'gencCode': 'LKA'},
#  {'countryCode': 5460,
#   'countryName': 'BURMA   ',
#   'countryDescription': 'BURMA                          ',
#   'regionId': 9,
#   'gencCode': 'MMR'},
#  {'countryCode': 5490,
#   'countryName': 'THAILND ',
#   'countryDescription': 'THAILAND                       ',
#   'regionId': 9,
#   'gencCode': 'THA'},
#  {'countryCode': 5510,
#   'countryName': 'S VETNM ',
#   'countryDescription': 'VIETNAM, REPUBLIC OF (SOUTH)   ',
#   'regionId': 9,
#   'gencCode': None},
#  {'countryCode': 5520,
#   'countryName': 'VIETNAM ',
#   'countryDescription': 'VIETNAM                        ',
#   'regionId': 9,
#   'gencCode': 'VNM'},
#  {'countryCode': 5530,
#   'countryName': 'LAOS    ',
#   'countryDescription': 'LAOS                           ',
#   'regionId': 9,
#   'gencCode': 'LAO'},
#  {'countryCode': 5550,
#   'countryName': 'CAMBODIA',
#   'countryDescription': 'CAMBODIA                       ',
#   'regionId': 9,
#   'gencCode': 'KHM'},
#  {'countryCode': 5570,
#   'countryName': 'MALAYSA ',
#   'countryDescription': 'MALAYSIA                       ',
#   'regionId': 9,
#   'gencCode': 'MYS'},
#  {'countryCode': 5590,
#   'countryName': 'SINGAPR ',
#   'countryDescription': 'SINGAPORE                      ',
#   'regionId': 9,
#   'gencCode': 'SGP'},
#  {'countryCode': 5600,
#   'countryName': 'INDNSIA ',
#   'countryDescription': 'INDONESIA                      ',
#   'regionId': 9,
#   'gencCode': 'IDN'},
#  {'countryCode': 5610,
#   'countryName': 'BRUNEI  ',
#   'countryDescription': 'BRUNEI                         ',
#   'regionId': 9,
#   'gencCode': 'BRN'},
#  {'countryCode': 5650,
#   'countryName': 'PHIL    ',
#   'countryDescription': 'PHILIPPINES                    ',
#   'regionId': 9,
#   'gencCode': 'PHL'},
#  {'countryCode': 5660,
#   'countryName': 'MACAU   ',
#   'countryDescription': 'MACAU                          ',
#   'regionId': 9,
#   'gencCode': 'MAC'},
#  {'countryCode': 5680,
#   'countryName': 'SO ASIA ',
#   'countryDescription': 'SOUTHERN ASIA                  ',
#   'regionId': 9,
#   'gencCode': None},
#  {'countryCode': 5700,
#   'countryName': 'CHINA   ',
#   'countryDescription': 'CHINA, PEOPLES REPUBLIC OF     ',
#   'regionId': 7,
#   'gencCode': 'CHN'},
#  {'countryCode': 5740,
#   'countryName': 'MONGOLIA',
#   'countryDescription': 'MONGOLIA                       ',
#   'regionId': 9,
#   'gencCode': 'MNG'},
#  {'countryCode': 5790,
#   'countryName': 'NO KOR  ',
#   'countryDescription': "KOREA, DEMOCRATIC PEOPLE'S REP ",
#   'regionId': 9,
#   'gencCode': None},
#  {'countryCode': 5800,
#   'countryName': 'KOR REP ',
#   'countryDescription': 'KOREA, REPUBLIC OF             ',
#   'regionId': 9,
#   'gencCode': None},
#  {'countryCode': 5820,
#   'countryName': 'HG KONG ',
#   'countryDescription': 'HONG KONG                      ',
#   'regionId': 9,
#   'gencCode': 'HKG'},
#  {'countryCode': 5830,
#   'countryName': 'TAIWAN  ',
#   'countryDescription': 'TAIWAN                         ',
#   'regionId': 6,
#   'gencCode': 'TWN'},
#  {'countryCode': 5880,
#   'countryName': 'JAPAN   ',
#   'countryDescription': 'JAPAN                          ',
#   'regionId': 5,
#   'gencCode': 'JPN'},
#  {'countryCode': 6020,
#   'countryName': 'AUSTRAL ',
#   'countryDescription': 'AUSTRALIA                      ',
#   'regionId': 9,
#   'gencCode': 'AUS'},
#  {'countryCode': 6040,
#   'countryName': 'NEW GUI ',
#   'countryDescription': 'PAPUA NEW GUINEA               ',
#   'regionId': 9,
#   'gencCode': 'PNG'},
#  {'countryCode': 6140,
#   'countryName': 'N ZEAL  ',
#   'countryDescription': 'NEW ZEALAND                    ',
#   'regionId': 9,
#   'gencCode': 'NZL'},
#  {'countryCode': 6150,
#   'countryName': 'W SAMOA ',
#   'countryDescription': 'WESTERN SAMOA                  ',
#   'regionId': 9,
#   'gencCode': None},
#  {'countryCode': 6220,
#   'countryName': 'BR P IS ',
#   'countryDescription': 'BRITISH PACIFIC ISLANDS        ',
#   'regionId': 9,
#   'gencCode': None},
#  {'countryCode': 6410,
#   'countryName': 'FR P IS ',
#   'countryDescription': 'FRENCH PACIFIC ISLANDS         ',
#   'regionId': 9,
#   'gencCode': None},
#  {'countryCode': 6810,
#   'countryName': 'MARSHALL',
#   'countryDescription': 'MARSHALL ISLANDS               ',
#   'regionId': 9,
#   'gencCode': 'MHL'},
#  {'countryCode': 6820,
#   'countryName': 'MICRONES',
#   'countryDescription': 'FEDERATED STATES OF MICRONESIA ',
#   'regionId': 9,
#   'gencCode': 'FSM'},
#  {'countryCode': 6830,
#   'countryName': 'PALAU   ',
#   'countryDescription': 'PALAU                          ',
#   'regionId': 9,
#   'gencCode': 'PLW'},
#  {'countryCode': 6840,
#   'countryName': 'T PAC I ',
#   'countryDescription': 'TRUST TERRITORY OF THE PACIFIC ',
#   'regionId': 9,
#   'gencCode': None},
#  {'countryCode': 6860,
#   'countryName': 'OPAC IS ',
#   'countryDescription': 'OTHER PACIFIC ISLANDS, NEC     ',
#   'regionId': 9,
#   'gencCode': None},
#  {'countryCode': 7140,
#   'countryName': 'MOROCCO ',
#   'countryDescription': 'MOROCCO                        ',
#   'regionId': 10,
#   'gencCode': 'MAR'},
#  {'countryCode': 7210,
#   'countryName': 'ALGERIA ',
#   'countryDescription': 'ALGERIA                        ',
#   'regionId': 10,
#   'gencCode': 'DZA'},
#  {'countryCode': 7230,
#   'countryName': 'TUNISIA ',
#   'countryDescription': 'TUNISIA                        ',
#   'regionId': 10,
#   'gencCode': 'TUN'},
#  {'countryCode': 7250,
#   'countryName': 'LIBYA   ',
#   'countryDescription': 'LIBYA                          ',
#   'regionId': 10,
#   'gencCode': 'LBY'},
#  {'countryCode': 7290,
#   'countryName': 'EGYPT   ',
#   'countryDescription': 'EGYPT                          ',
#   'regionId': 10,
#   'gencCode': 'EGY'},
#  {'countryCode': 7320,
#   'countryName': 'SUDAN   ',
#   'countryDescription': 'SUDAN                          ',
#   'regionId': 10,
#   'gencCode': 'SDN'},
#  {'countryCode': 7323,
#   'countryName': 'South su',
#   'countryDescription': 'south sudan                    ',
#   'regionId': 10,
#   'gencCode': None},
#  {'countryCode': 7330,
#   'countryName': 'CNRY I  ',
#   'countryDescription': 'CANARY ISLANDS                 ',
#   'regionId': 10,
#   'gencCode': None},
#  {'countryCode': 7370,
#   'countryName': 'W SAHARA',
#   'countryDescription': 'WESTERN SAHARA                 ',
#   'regionId': 10,
#   'gencCode': 'ESH'},
#  {'countryCode': 7380,
#   'countryName': 'EQ GUIN ',
#   'countryDescription': 'EQUATORIAL GUINEA              ',
#   'regionId': 10,
#   'gencCode': 'GNQ'},
#  {'countryCode': 7410,
#   'countryName': 'MAURITN ',
#   'countryDescription': 'MAURITANIA                     ',
#   'regionId': 10,
#   'gencCode': 'MRT'},
#  {'countryCode': 7420,
#   'countryName': 'CAMROON ',
#   'countryDescription': 'CAMEROON                       ',
#   'regionId': 10,
#   'gencCode': 'CMR'},
#  {'countryCode': 7440,
#   'countryName': 'SENEGAL ',
#   'countryDescription': 'SENEGAL                        ',
#   'regionId': 10,
#   'gencCode': 'SEN'},
#  {'countryCode': 7450,
#   'countryName': 'MALI    ',
#   'countryDescription': 'MALI                           ',
#   'regionId': 10,
#   'gencCode': 'MLI'},
#  {'countryCode': 7460,
#   'countryName': 'GUIN-CON',
#   'countryDescription': 'GUINEA                         ',
#   'regionId': 10,
#   'gencCode': 'GIN'},
#  {'countryCode': 7470,
#   'countryName': 'SIER LN ',
#   'countryDescription': 'SIERRA LEONE                   ',
#   'regionId': 10,
#   'gencCode': 'SLE'},
#  {'countryCode': 7480,
#   'countryName': 'C IVOIRE',
#   'countryDescription': "COTE D'IVOIRE                  ",
#   'regionId': 10,
#   'gencCode': None},
#  {'countryCode': 7490,
#   'countryName': 'GHANA   ',
#   'countryDescription': 'GHANA                          ',
#   'regionId': 10,
#   'gencCode': 'GHA'},
#  {'countryCode': 7500,
#   'countryName': 'GAMBIA  ',
#   'countryDescription': 'GAMBIA, THE                    ',
#   'regionId': 10,
#   'gencCode': 'GMB'},
#  {'countryCode': 7510,
#   'countryName': 'NIGER   ',
#   'countryDescription': 'NIGER                          ',
#   'regionId': 10,
#   'gencCode': 'NER'},
#  {'countryCode': 7520,
#   'countryName': 'TOGO    ',
#   'countryDescription': 'TOGO                           ',
#   'regionId': 10,
#   'gencCode': 'TGO'},
#  {'countryCode': 7530,
#   'countryName': 'NIGERIA ',
#   'countryDescription': 'NIGERIA                        ',
#   'regionId': 10,
#   'gencCode': 'NGA'},
#  {'countryCode': 7540,
#   'countryName': 'C AF EMP',
#   'countryDescription': 'CENTRAL AFRICAN REPUBLIC       ',
#   'regionId': 10,
#   'gencCode': 'CAF'},
#  {'countryCode': 7550,
#   'countryName': 'GABON   ',
#   'countryDescription': 'GABON                          ',
#   'regionId': 10,
#   'gencCode': 'GAB'},
#  {'countryCode': 7560,
#   'countryName': 'CHAD    ',
#   'countryDescription': 'CHAD                           ',
#   'regionId': 10,
#   'gencCode': 'TCD'},
#  {'countryCode': 7580,
#   'countryName': 'S HELENA',
#   'countryDescription': 'ST. HELENA (BR W AFR)          ',
#   'regionId': 10,
#   'gencCode': None},
#  {'countryCode': 7590,
#   'countryName': 'MADIERA ',
#   'countryDescription': 'MADEIRA ISLANDS                ',
#   'regionId': 10,
#   'gencCode': None},
#  {'countryCode': 7600,
#   'countryName': 'BUR FASO',
#   'countryDescription': 'BURKINA FASO                   ',
#   'regionId': 10,
#   'gencCode': None},
#  {'countryCode': 7610,
#   'countryName': 'BENIN   ',
#   'countryDescription': 'BENIN                          ',
#   'regionId': 10,
#   'gencCode': 'BEN'},
#  {'countryCode': 7620,
#   'countryName': 'ANGOLA  ',
#   'countryDescription': 'ANGOLA                         ',
#   'regionId': 10,
#   'gencCode': 'AGO'},
#  {'countryCode': 7630,
#   'countryName': 'CO BRAZ ',
#   'countryDescription': 'CONGO (BRAZZAVILLE)            ',
#   'regionId': 10,
#   'gencCode': 'COG'},
#  {'countryCode': 7640,
#   'countryName': 'GUIN-BIS',
#   'countryDescription': 'WESTERN AFRICA, NEC            ',
#   'regionId': 10,
#   'gencCode': None},
#  {'countryCode': 7650,
#   'countryName': 'LIBERIA ',
#   'countryDescription': 'LIBERIA                        ',
#   'regionId': 10,
#   'gencCode': 'LBR'},
#  {'countryCode': 7660,
#   'countryName': 'CONGO DR',
#   'countryDescription': 'CONGO, DEMOCRATIC REPUBLIC OF  ',
#   'regionId': 10,
#   'gencCode': None},
#  {'countryCode': 7670,
#   'countryName': 'BURUNDI ',
#   'countryDescription': 'BURUNDI                        ',
#   'regionId': 10,
#   'gencCode': 'BDI'},
#  {'countryCode': 7690,
#   'countryName': 'RWANDA  ',
#   'countryDescription': 'RWANDA                         ',
#   'regionId': 10,
#   'gencCode': 'RWA'},
#  {'countryCode': 7700,
#   'countryName': 'SOM REP ',
#   'countryDescription': 'SOMALIA                        ',
#   'regionId': 10,
#   'gencCode': 'SOM'},
#  {'countryCode': 7740,
#   'countryName': 'ETHIOP  ',
#   'countryDescription': 'ETHIOPIA                       ',
#   'regionId': 10,
#   'gencCode': 'ETH'},
#  {'countryCode': 7741,
#   'countryName': 'ERITREA ',
#   'countryDescription': 'ERITREA                        ',
#   'regionId': 10,
#   'gencCode': 'ERI'},
#  {'countryCode': 7770,
#   'countryName': 'DJIBOUTI',
#   'countryDescription': 'DJIBOUTI AFARS-ISSAS           ',
#   'regionId': 10,
#   'gencCode': 'DJI'},
#  {'countryCode': 7780,
#   'countryName': 'UGANDA  ',
#   'countryDescription': 'UGANDA                         ',
#   'regionId': 10,
#   'gencCode': 'UGA'},
#  {'countryCode': 7790,
#   'countryName': 'KENYA   ',
#   'countryDescription': 'KENYA                          ',
#   'regionId': 10,
#   'gencCode': 'KEN'},
#  {'countryCode': 7800,
#   'countryName': 'SEYCHEL ',
#   'countryDescription': 'SEYCHELLES AND DEPENDENTS      ',
#   'regionId': 10,
#   'gencCode': None},
#  {'countryCode': 7810,
#   'countryName': 'B IND O ',
#   'countryDescription': 'BRITISH INDIAN OCEAN TERRITORY ',
#   'regionId': 10,
#   'gencCode': 'IOT'},
#  {'countryCode': 7830,
#   'countryName': 'TNZANIA ',
#   'countryDescription': 'TANZANIA, UNITED REPUBLIC OF   ',
#   'regionId': 10,
#   'gencCode': None},
#  {'countryCode': 7850,
#   'countryName': 'MAURIT  ',
#   'countryDescription': 'MAURITIUS AND DEPENDENTS       ',
#   'regionId': 10,
#   'gencCode': None},
#  {'countryCode': 7870,
#   'countryName': 'MOZAMBQ ',
#   'countryDescription': 'MOZAMBIQUE                     ',
#   'regionId': 10,
#   'gencCode': 'MOZ'},
#  {'countryCode': 7880,
#   'countryName': 'MADAGASR',
#   'countryDescription': 'MADAGASCAR                     ',
#   'regionId': 10,
#   'gencCode': 'MDG'},
#  {'countryCode': 7890,
#   'countryName': 'COMOROS ',
#   'countryDescription': 'COMOROS                        ',
#   'regionId': 10,
#   'gencCode': 'COM'},
#  {'countryCode': 7900,
#   'countryName': 'F IND O ',
#   'countryDescription': 'FRENCH IND. OCEAN TERRITORY    ',
#   'regionId': 10,
#   'gencCode': None},
#  {'countryCode': 7910,
#   'countryName': 'REP SAF ',
#   'countryDescription': 'SOUTH AFRICA, REPUBLIC OF      ',
#   'regionId': 10,
#   'gencCode': None},
#  {'countryCode': 7920,
#   'countryName': 'NAMIBIA ',
#   'countryDescription': 'NAMIBIA                        ',
#   'regionId': 10,
#   'gencCode': 'NAM'},
#  {'countryCode': 7930,
#   'countryName': 'BOTSWANA',
#   'countryDescription': 'BOTSWANA                       ',
#   'regionId': 10,
#   'gencCode': 'BWA'},
#  {'countryCode': 7940,
#   'countryName': 'ZAMBIA  ',
#   'countryDescription': 'ZAMBIA                         ',
#   'regionId': 10,
#   'gencCode': 'ZMB'},
#  {'countryCode': 7950,
#   'countryName': 'SWAZLND ',
#   'countryDescription': 'SWAZILAND                      ',
#   'regionId': 10,
#   'gencCode': None},
#  {'countryCode': 7960,
#   'countryName': 'ZIMBABWE',
#   'countryDescription': 'ZIMBABWE                       ',
#   'regionId': 10,
#   'gencCode': 'ZWE'},
#  {'countryCode': 7970,
#   'countryName': 'MALAWI  ',
#   'countryDescription': 'MALAWI                         ',
#   'regionId': 10,
#   'gencCode': 'MWI'},
#  {'countryCode': 7990,
#   'countryName': 'LESOTHO ',
#   'countryDescription': 'LESOTHO                        ',
#   'regionId': 10,
#   'gencCode': 'LSO'},
#  {'countryCode': 9110,
#   'countryName': 'VIRGIN I',
#   'countryDescription': 'VIRGIN ISLANDS OF THE U.S.     ',
#   'regionId': 11,
#   'gencCode': None},
#  {'countryCode': 9310,
#   'countryName': 'MIDWAY I',
#   'countryDescription': 'MIDWAY ISLANDS                 ',
#   'regionId': 9,
#   'gencCode': None},
#  {'countryCode': 9330,
#   'countryName': 'WAKE IS ',
#   'countryDescription': 'WAKE ISLAND                    ',
#   'regionId': 9,
#   'gencCode': None},
#  {'countryCode': 9350,
#   'countryName': 'GUAM    ',
#   'countryDescription': 'GUAM                           ',
#   'regionId': 9,
#   'gencCode': 'GUM'},
#  {'countryCode': 9410,
#   'countryName': 'CAN EN I',
#   'countryDescription': 'CANTON AND ENDERBURY ISLANDS   ',
#   'regionId': 9,
#   'gencCode': None},
#  {'countryCode': 9510,
#   'countryName': 'AM SAMOA',
#   'countryDescription': 'AMERICAN SAMOA                 ',
#   'regionId': 9,
#   'gencCode': 'ASM'},
#  {'countryCode': 9610,
#   'countryName': 'NMARIANA',
#   'countryDescription': 'NORTHERN MARIANA ISLANDS       ',
#   'regionId': 9,
#   'gencCode': 'MNP'},
#  {'countryCode': 9800,
#   'countryName': 'US O IS ',
#   'countryDescription': 'US MINOR OUTLYING ISLAND       ',
#   'regionId': 9,
#   'gencCode': None}]

# %%
## now let's put into get requests
## we check the response status code
response = requests.get(url = com_url, headers = headers)
response.json()
# Out:
# 'Bad API Key'

# %% [markdown]
# ### Get endpoint and test out on a single commodity

# %%
## your end point here

# %%
## now let's put into get requests
## we check the response status code

# %%
## let's store our response into an object called data

# %%
## convert that list of dicts into a dataframe called df

# %%
## Now iterate through all our target items

# %%
## endpoint templates

# %%
## iterate to get all the data

# %%
## call list

# %%
## concat into single df

# %%
## call df

# %%
## confirm we have all our target commodities

# %% [markdown]
# ### 3. <a id="federal"></a>Federal Register – **tapping search terms.**
#
# We have decades of <a href="https://docs.google.com/spreadsheets/d/130WeumbMZjcoRP4D-1uJ7bM0aKBZzt4N/edit?usp=sharing&ouid=112307892189798608417&rtpof=true&sd=true">SBA Excel files</a> that detail loans given to small businesses to recover after climate disasters. The only information we have about the type of disasters are codes in one of the columns that look like:
#
# - CA-00279
# - IL-00051
# - NC-00099
# - CA-00288
# - LA-00079
#
# The <a href="https://www.federalregister.gov/">Federal Register</a> allows us to search for what these codes stand for. But we can't search for nearly a thousand such disaster codes. When we try to scrape the site, it warns us to use the API instead.
#
# Federal Register <a href="https://www.federalregister.gov/developers/documentation/api/v1#/Federal%20Register%20Documents/get_documents__format_">API documentation</a>

# %% [markdown]
# ## find the end point
#
# https://www.federalregister.gov/api/v1/documents.json?per_page=20&conditions[docket_id]=LA-00079
#
# https://www.federalregister.gov/api/v1/documents.json?per_page=20&conditions[docket_id]=PA-00115

# %% [markdown]
# #### Test on single endpoint after figuring out how to build API call

# %%
## endpoint
endpoint = "https://www.federalregister.gov/api/v1/documents.json?per_page=20&conditions[docket_id]=PA-00115"

# %%
## get data
response = requests.get(endpoint)
data = response.json()
data
# Out:
# {'count': 1,
#  'description': 'Documents filed under agency docket PA-00115',
#  'total_pages': 1,
#  'results': [{'title': 'Administrative Declaration of a Disaster for the Commonwealth of Pennsylvania',
#    'type': 'Notice',
#    'abstract': 'This is a notice of an Administrative declaration of a disaster for the State of Pennsylvania dated 10/6/2021. Incident: Remnants of Tropical Depression Ida. Incident Period: 09/01/2021 through 09/03/2021.',
#    'document_number': '2021-22189',
#    'html_url': 'https://www.federalregister.gov/documents/2021/10/13/2021-22189/administrative-declaration-of-a-disaster-for-the-commonwealth-of-pennsylvania',
#    'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2021-10-13/pdf/2021-22189.pdf',
#    'public_inspection_pdf_url': 'https://public-inspection.federalregister.gov/2021-22189.pdf?1634042723',
#    'publication_date': '2021-10-13',
#    'agencies': [{'raw_name': 'SMALL BUSINESS ADMINISTRATION',
#      'name': 'Small Business Administration',
#      'id': 468,
#      'url': 'https://www.federalregister.gov/agencies/small-business-administration',
#      'json_url': 'https://www.federalregister.gov/api/v1/agencies/468',
#      'parent_id': None,
#      'slug': 'small-business-administration'}],
#    'excerpts': 'This is a notice of an Administrative declaration of a disaster for the State of Pennsylvania dated 10/6/2021. Incident: Remnants of Tropical Depression Ida. Incident Period: 09/01/2021 through 09/03/2021.'}]}

# %%
## length
len(data)
# Out:
# 4

# %%
## what type is it?
type(data)
# Out:
# dict

# %%
data.get("count")
# Out:
# 1

# %%
data.get("results")
# Out:
# [{'title': 'Administrative Declaration of a Disaster for the Commonwealth of Pennsylvania',
#   'type': 'Notice',
#   'abstract': 'This is a notice of an Administrative declaration of a disaster for the State of Pennsylvania dated 10/6/2021. Incident: Remnants of Tropical Depression Ida. Incident Period: 09/01/2021 through 09/03/2021.',
#   'document_number': '2021-22189',
#   'html_url': 'https://www.federalregister.gov/documents/2021/10/13/2021-22189/administrative-declaration-of-a-disaster-for-the-commonwealth-of-pennsylvania',
#   'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2021-10-13/pdf/2021-22189.pdf',
#   'public_inspection_pdf_url': 'https://public-inspection.federalregister.gov/2021-22189.pdf?1634042723',
#   'publication_date': '2021-10-13',
#   'agencies': [{'raw_name': 'SMALL BUSINESS ADMINISTRATION',
#     'name': 'Small Business Administration',
#     'id': 468,
#     'url': 'https://www.federalregister.gov/agencies/small-business-administration',
#     'json_url': 'https://www.federalregister.gov/api/v1/agencies/468',
#     'parent_id': None,
#     'slug': 'small-business-administration'}],
#   'excerpts': 'This is a notice of an Administrative declaration of a disaster for the State of Pennsylvania dated 10/6/2021. Incident: Remnants of Tropical Depression Ida. Incident Period: 09/01/2021 through 09/03/2021.'}]

# %%
## type
type(data.get("results"))
# Out:
# list

# %%
len((data.get("results")))
# Out:
# 1

# %%
data.get("results")[0]
# Out:
# {'title': 'Administrative Declaration of a Disaster for the Commonwealth of Pennsylvania',
#  'type': 'Notice',
#  'abstract': 'This is a notice of an Administrative declaration of a disaster for the State of Pennsylvania dated 10/6/2021. Incident: Remnants of Tropical Depression Ida. Incident Period: 09/01/2021 through 09/03/2021.',
#  'document_number': '2021-22189',
#  'html_url': 'https://www.federalregister.gov/documents/2021/10/13/2021-22189/administrative-declaration-of-a-disaster-for-the-commonwealth-of-pennsylvania',
#  'pdf_url': 'https://www.govinfo.gov/content/pkg/FR-2021-10-13/pdf/2021-22189.pdf',
#  'public_inspection_pdf_url': 'https://public-inspection.federalregister.gov/2021-22189.pdf?1634042723',
#  'publication_date': '2021-10-13',
#  'agencies': [{'raw_name': 'SMALL BUSINESS ADMINISTRATION',
#    'name': 'Small Business Administration',
#    'id': 468,
#    'url': 'https://www.federalregister.gov/agencies/small-business-administration',
#    'json_url': 'https://www.federalregister.gov/api/v1/agencies/468',
#    'parent_id': None,
#    'slug': 'small-business-administration'}],
#  'excerpts': 'This is a notice of an Administrative declaration of a disaster for the State of Pennsylvania dated 10/6/2021. Incident: Remnants of Tropical Depression Ida. Incident Period: 09/01/2021 through 09/03/2021.'}

# %%
## targeting incidents
data.get("results")[0].get("abstract")
# Out:
# 'This is a notice of an Administrative declaration of a disaster for the State of Pennsylvania dated 10/6/2021. Incident: Remnants of Tropical Depression Ida. Incident Period: 09/01/2021 through 09/03/2021.'

# %% [markdown]
# ### Iterate through entire list of codes

# %%
## Normally will take from df as a list
## build disaster code list
disaster_codes = ["CA-00279","IL-00051", "NC-00099", "CA-00288", "LA-00079"]

# %%
## provide base url
base_url = "https://www.federalregister.gov/api/v1/documents.json?per_page=20&conditions[docket_id]="

# %%
broken_endpoints = [] ## track broken endpoints
incidents_list = []

## iterate through all endpoints
for disaster_code in disaster_codes:
    endpoint = base_url + disaster_code
    try:
        response = requests.get(endpoint)
        data = response.json()
        incident_text = data.get("results")[0].get("abstract")
        incidents_list.append({"disaster_code": disaster_code,
                              "description": incident_text})
    except:
        broken_endpoints.append(endpoint)

# %%
## call list
incidents_list
# Out:
# [{'disaster_code': 'CA-00279',
#   'description': 'This is an amendment of the Presidential declaration of a major disaster for the State of California (FEMA-4344-DR), dated 10/12/ 2017. Incident: Wildfires. Incident Period: 10/08/2017 through 10/31/2017.'},
#  {'disaster_code': 'IL-00051',
#   'description': 'This is a notice of an Administrative declaration of a disaster for the State of Illinois dated 05/07/2018. Incident: Severe Storms and Flooding. Incident Period: 02/14/2018 through 03/04/2018.'},
#  {'disaster_code': 'NC-00099',
#   'description': 'This is an amendment of the Presidential declaration of a major disaster for the State of North Carolina (FEMA-4393-DR), dated 09/14/2018. Incident: Hurricane Florence. Incident Period: 09/07/2018 through 09/29/2018.'},
#  {'disaster_code': 'CA-00288',
#   'description': 'This is an amendment of the Presidential declaration of a major disaster for the State of California (FEMA-4382-DR), dated 08/04/ 2018. Incident: Wildfires and High Winds. Incident Period: 07/23/2018 through 09/19/2018.'},
#  {'disaster_code': 'LA-00079',
#   'description': 'This is a notice of an Administrative declaration of a disaster for the State of Louisiana dated 01/02/2018. Incident: Tropical Storm Harvey. Incident Period: 08/27/2017 through 09/10/2017.'}]

# %%
pd.DataFrame(incidents_list)
# Out:
#   disaster_code                                        description
# 0      CA-00279  This is an amendment of the Presidential decla...
# 1      IL-00051  This is a notice of an Administrative declarat...
# 2      NC-00099  This is an amendment of the Presidential decla...
# 3      CA-00288  This is an amendment of the Presidential decla...
# 4      LA-00079  This is a notice of an Administrative declarat...

# %%
actual_incidents = []
for item in incidents_list:
    print(item.get("description"))
    try:
        incident_text = \
        item["description"].split("Incident:")[1].split(". Incident Period:")[0].strip()
# Out:
#   Cell In[33], line 6
#     item["description"].split("Incident:")[1].split(". Incident Period:")[0].strip()
#
# ^
# SyntaxError: unexpected EOF while parsing

# %%
## your target endpoint

# %% [markdown]
# ### 4. Energy Information Administration – **dealing with pagination.**
#
# From the <a href="https://www.eia.gov/">Energy Information Administration</a>, we want to compile energy generation by type of fuel and region for about 5 days.
#
# We will encounter a limit on the number of items per API call.
#
# Find our API endpoint first.

# %%
## get response

# %%
## import ceiling division from math

# %%
## paginate our API calls

# %%
## for loop with pagination

# %%
## call all data

# %%
## length

# %%
## use itertools to flatten list with nested lists

# %%
## flatten nested lists

# %%
## convert to df

# %%
fips_codes = {
    'Alabama': '01',
    'Alaska': '02',
    'Arizona': '04',
    'Arkansas': '05',
    'California': '06',
    'Colorado': '08',
    'Connecticut': '09',
    'Delaware': '10',
    'Florida': '12',
    'Georgia': '13',
    'Hawaii': '15',
    'Idaho': '16',
    'Illinois': '17',
    'Indiana': '18',
    'Iowa': '19',
    'Kansas': '20',
    'Kentucky': '21',
    'Louisiana': '22',
    'Maine': '23',
    'Maryland': '24',
    'Massachusetts': '25',
    'Michigan': '26',
    'Minnesota': '27',
    'Mississippi': '28',
    'Missouri': '29',
    'Montana': '30',
    'Nebraska': '31',
    'Nevada': '32',
    'New Hampshire': '33',
    'New Jersey': '34',
    'New Mexico': '35',
    'New York': '36',
    'North Carolina': '37',
    'North Dakota': '38',
    'Ohio': '39',
    'Oklahoma': '40',
    'Oregon': '41',
    'Pennsylvania': '42',
    'Rhode Island': '44',
    'South Carolina': '45',
    'South Dakota': '46',
    'Tennessee': '47',
    'Texas': '48',
    'Utah': '49',
    'Vermont': '50',
    'Virginia': '51',
    'Washington': '53',
    'West Virginia': '54',
    'Wisconsin': '55',
    'Wyoming': '56',
    'District of Columbia': '11',
    'Puerto Rico': '72'
}
